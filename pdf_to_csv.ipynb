# %%
import PyPDF2
import pandas as pd
import os
from pprint import pprint
import re
import numpy as np

# %%
def process_pdf(pdf_reader: PyPDF2.PdfReader, out_filename: str, verbose=False):
    
    pattern = r"(\d+)\s+([\u4e00-\u9fff｜（）、〇]+)\s+((?:(?:(?:\w*[āáǎàēéěèīíǐìōóǒòūúǔùüǘǚǜ][\w']*)|le|zi|ma|ba|de|di|ge|jie|men|ren|ne|zhe)[\s｜（）·]+)+)([^\n]+)"
    
    def sprint(string): # sanity print
        print(string) if verbose else None
    
    with open(out_filename, "a+") as out_file:
        for page in pdf_reader.pages:
            page_text = page.extract_text()

            # since some entries are multi-lined, need to concat lines together
            # main idea here is to pay attention to entry number
            # we won't process an entry until we know that we have all the relevant data for that entry
            # this can only be gauranteed until we come across the starting point of the next entry
            current_entry = ""
            for line in page_text.split("\n"):
                # perform some cleaning on the current line
                line = re.sub(r"[ ]+", " ", line)

                # check to see if we've hit the start of the next entry
                if re.search(r"[\u4e00-\u9fff]", line):
                    # if so, start processing the current entry
                    sprint(f"ENTRY START\n{current_entry}\nENTRY END\n\n")

                    find_result = re.findall(
                        pattern,
                        current_entry,
                    )

                    if len(find_result):  # check if we found a match
                        (num, chars, pingyin, definition) = find_result[0]
                        num = num.replace("\n", " ").strip()
                        chars = chars.replace("\n", " ").strip()
                        pingyin = pingyin.replace("\n", " ").strip()
                        definition = definition.replace("\n", " ").strip()

                        entry_text = f"{num}[-] {chars}[-] {pingyin}[-] {definition}\n"
                        out_file.write(entry_text)
                    else:
                        # check to see if we should've found a match
                        if re.search(r"[\u4e00-\u9fff]", current_entry):
                            entry_text = f"***{current_entry}\n"
                            out_file.write(entry_text)
                        else:
                            pass

                    # update current_entry to be the new entry
                    current_entry = line
                else:
                    # if we haven't yet stumbled across the start of the next entry, keep concatenating new lines to the current entry
                    current_entry = f"{current_entry}\n{line}"

# %%
pdf_dir = os.path.join(os.getcwd(), "data", "pdf")
pdf_files = sorted(
    [os.path.join(pdf_dir, pdf_name) for pdf_name in os.listdir(pdf_dir)]
)
pdf_files
# Out:
# ['/Users/elim-mbp-01/Documents/cngrind/third_pass/data/pdf/New-HSK-1-Word-List.pdf',
#  '/Users/elim-mbp-01/Documents/cngrind/third_pass/data/pdf/New-HSK-2-Word-List.pdf',
#  '/Users/elim-mbp-01/Documents/cngrind/third_pass/data/pdf/New-HSK-3-Word-List.pdf',
#  '/Users/elim-mbp-01/Documents/cngrind/third_pass/data/pdf/New-HSK-4-Word-List.pdf',
#  '/Users/elim-mbp-01/Documents/cngrind/third_pass/data/pdf/New-HSK-5-Word-List.pdf',
#  '/Users/elim-mbp-01/Documents/cngrind/third_pass/data/pdf/New-HSK-6-Word-List.pdf']

# %%
for pdf_file in pdf_files:
    pdf_reader = PyPDF2.PdfReader(pdf_file)
    pdf_name = pdf_file.split("/")[-1].strip(".pdf")
    print(pdf_name, len(pdf_reader.pages))
    
    process_pdf(pdf_reader, f"{pdf_name}.csv", verbose=True)
# Out:
# New-HSK-1-Word-List 25
# ENTRY START
#
# 1
#  No Chinese Pinyin English
# ENTRY END
#
#
# ENTRY START
# 1 爱 ài love
# ENTRY END
#
#
# ENTRY START
# 2 爱好 ài hào hobby
# ENTRY END
#
#
# ENTRY START
# 3 八 bā eight
# ENTRY END
#
#
# ENTRY START
# 4 爸爸｜爸 bàba ｜ bà dad
# ENTRY END
#
#
# ENTRY START
# 5 吧 ba (interjection particle)
# ENTRY END
#
#
# ENTRY START
# 6 白（形） bái white
# ENTRY END
#
#
# ENTRY START
# 7 白天 bái tiān day
# ENTRY END
#
#
# ENTRY START
# 8 百 bǎi hundred
# ENTRY END
#
#
# ENTRY START
# 9 班 bān class
# ENTRY END
#
#
# ENTRY START
# 10 半 bàn half
# ENTRY END
#
#
# ENTRY START
# 11 半年 bàn nián half a year
# ENTRY END
#
#
# ENTRY START
# 12 半天 bàn tiān half day
# ENTRY END
#
#
# ENTRY START
# 13 帮 bāng help
# ENTRY END
#
#
# ENTRY START
# 14 帮忙 bāng máng help
# ENTRY END
#
#
# ENTRY START
# 15 包 bāo package
# ENTRY END
#
#
# ENTRY START
# 16 包子 bāo zi bun
# ENTRY END
#
#
# ENTRY START
# 17 杯 bēi cup
# ENTRY END
#
#
# ENTRY START
# 18 杯子 bēi zi cup
# ENTRY END
#
#
# ENTRY START
# 19 北 běi north
# ENTRY END
#
#
# ENTRY START
# 20 北边 běi biān North side
# ENTRY END
#
#
# ENTRY START
#
# 2
# ENTRY END
#
#
# ENTRY START
#  22 本（量） běn (measure word for books or volumes)
# ENTRY END
#
#
# ENTRY START
# 23 本子 běn zi book
# ENTRY END
#
#
# ENTRY START
# 24 比 bǐ particle used for comparison
# ENTRY END
#
#
# ENTRY START
# 25 别（副） bié Don't
# ENTRY END
#
#
# ENTRY START
# 26 别的 bié de other
# ENTRY END
#
#
# ENTRY START
# 27 别人 bié·rén other people
# ENTRY END
#
#
# ENTRY START
# 28 病 bìng disease
# ENTRY END
#
#
# ENTRY START
# 29 病人 bìng rén patient
# ENTRY END
#
#
# ENTRY START
# 30 不大 bú dà not big
# ENTRY END
#
#
# ENTRY START
# 31 不对 bú duì wrong
# ENTRY END
#
#
# ENTRY START
# 32 不客气 bú kè qì You're welcome
# ENTRY END
#
#
# ENTRY START
# 33 不用 bú yòng No need to
# ENTRY END
#
#
# ENTRY START
# 34 不 bù No
# ENTRY END
#
#
# ENTRY START
# 35 菜 cài dish
# ENTRY END
#
#
# ENTRY START
# 36 茶 chá tea
# ENTRY END
#
#
# ENTRY START
# 37 差 chà differ from; bad; short of
# ENTRY END
#
#
# ENTRY START
# 38 常 cháng often
# ENTRY END
#
#
# ENTRY START
# 39 常常 cháng cháng often
# ENTRY END
#
#
# ENTRY START
# 40 唱 chàng sing
# ENTRY END
#
#
# ENTRY START
# 41 唱歌 chàng gē sing
# ENTRY END
#
#
# ENTRY START
# 42 车 chē car
# ENTRY END
#
#
# ENTRY START
#
# 3
# ENTRY END
#
#
# ENTRY START
#  44 车上 chē shàng in the car
# ENTRY END
#
#
# ENTRY START
# 45 车站 chē zhàn station
# ENTRY END
#
#
# ENTRY START
# 46 吃 chī eat
# ENTRY END
#
#
# ENTRY START
# 47 吃饭 chī fàn have meal
# ENTRY END
#
#
# ENTRY START
# 48 出 chū out
# ENTRY END
#
#
# ENTRY START
# 49 出来 chū lái come
# ENTRY END
#
#
# ENTRY START
# 50 出去 chū qù go out
# ENTRY END
#
#
# ENTRY START
# 51 穿 chuān wear
# ENTRY END
#
#
# ENTRY START
# 52 床 chuáng bed
# ENTRY END
#
#
# ENTRY START
# 53 次（量） cì (measure word for times, frequency)
# ENTRY END
#
#
# ENTRY START
# 54 从 cóng from
# ENTRY END
#
#
# ENTRY START
# 55 错 cuò wrong
# ENTRY END
#
#
# ENTRY START
# 56 打（动） dǎ hit, take
# ENTRY END
#
#
# ENTRY START
# 57 打车 dǎ chē take a taxi
# ENTRY END
#
#
# ENTRY START
# 58 打电话 dǎ diàn huà make a phonecall
# ENTRY END
#
#
# ENTRY START
# 59 打开 dǎ kāi turn on
# ENTRY END
#
#
# ENTRY START
# 60 打球 dǎ qiú play ball
# ENTRY END
#
#
# ENTRY START
# 61 大 dà large, big
# ENTRY END
#
#
# ENTRY START
# 62 大学 dà xué university
# ENTRY END
#
#
# ENTRY START
# 63 大学生 dà xué shēng university student
# ENTRY END
#
#
# ENTRY START
# 64 到 dào reach
# ENTRY END
#
#
# ENTRY START
#
# 4
# ENTRY END
#
#
# ENTRY START
#  66 地 de auxiliary word
# ENTRY END
#
#
# ENTRY START
# 67 的 de (aux.)
# ENTRY END
#
#
# ENTRY START
# 68 等（动） děng wait
# ENTRY END
#
#
# ENTRY START
# 69 地 dì ground
# ENTRY END
#
#
# ENTRY START
# 70 地点 dìdiǎn location
# ENTRY END
#
#
# ENTRY START
# 71 地方 dìfang local
# ENTRY END
#
#
# ENTRY START
# 72 地上 dì shàng on the ground
# ENTRY END
#
#
# ENTRY START
# 73 地图 dìtú Map
# ENTRY END
#
#
# ENTRY START
# 74 弟弟｜弟 dì di ｜ dì younger brother
# ENTRY END
#
#
# ENTRY START
# 75 第（第二） dì （ dì èr ） auxiliary word for ordinal numbers
# (second )
# ENTRY END
#
#
# ENTRY START
# 76 点 diǎn spot
# ENTRY END
#
#
# ENTRY START
# 77 电 diàn electricity
# ENTRY END
#
#
# ENTRY START
# 78 电话 diàn huà phone
# ENTRY END
#
#
# ENTRY START
# 79 电脑 diànnǎo Computer
# ENTRY END
#
#
# ENTRY START
# 80 电视 diànshì television
# ENTRY END
#
#
# ENTRY START
# 81 电视机 diàn shì jī television
# ENTRY END
#
#
# ENTRY START
# 82 电影 diànyǐng Film
# ENTRY END
#
#
# ENTRY START
# 83 电影院 diàn yǐng
# yuàn cinema; movie theater
# ENTRY END
#
#
# ENTRY START
# 84 东 dōng east
# ENTRY END
#
#
# ENTRY START
#
# 5
# ENTRY END
#
#
# ENTRY START
#  86 东西 dōngxi thing
# ENTRY END
#
#
# ENTRY START
# 87 动 dòng move
# ENTRY END
#
#
# ENTRY START
# 88 动作 dòngzuò action
# ENTRY END
#
#
# ENTRY START
# 89 都 dōu all
# ENTRY END
#
#
# ENTRY START
# 90 读 dú read
# ENTRY END
#
#
# ENTRY START
# 91 读书 dú shū reading; study
# ENTRY END
#
#
# ENTRY START
# 92 对（形） duì right
# ENTRY END
#
#
# ENTRY START
# 93 对不起 duìbuqǐ I'm sorry.
# ENTRY END
#
#
# ENTRY START
# 94 多（形、代） duō many; much; more
# ENTRY END
#
#
# ENTRY START
# 95 多少 duōshao how much
# ENTRY END
#
#
# ENTRY START
# 96 饿 è hungry
# ENTRY END
#
#
# ENTRY START
# 97 儿子 érzi Son
# ENTRY END
#
#
# ENTRY START
# 98 二 èr Two
# ENTRY END
#
#
# ENTRY START
# 99 饭 fàn rice; meal
# ENTRY END
#
#
# ENTRY START
# 100 饭店 fàndiàn restaurant
# ENTRY END
#
#
# ENTRY START
# 101 房间 fángjiān Room
# ENTRY END
#
#
# ENTRY START
# 102 房子 fáng zi house; building
# ENTRY END
#
#
# ENTRY START
# 103 放 fàng discharge
# ENTRY END
#
#
# ENTRY START
# 104 放假 fàng jià holiday; have a holiday
# ENTRY END
#
#
# ENTRY START
# 105 放学 fàng xué off school
# ENTRY END
#
#
# ENTRY START
# 106 飞 fēi fly
# ENTRY END
#
#
# ENTRY START
#
# 6
# ENTRY END
#
#
# ENTRY START
#  108 非常 fēicháng very
# ENTRY END
#
#
# ENTRY START
# 109 分（名、量） fēn minute; point; part; (measure word)
# ENTRY END
#
#
# ENTRY START
# 110 风 fēng wind
# ENTRY END
#
#
# ENTRY START
# 111 干 gān dry
# ENTRY END
#
#
# ENTRY START
# 112 干净 gānjìng clean
# ENTRY END
#
#
# ENTRY START
# 113 干 gàn do
# ENTRY END
#
#
# ENTRY START
# 114 干什么 gàn shén me What to do
# ENTRY END
#
#
# ENTRY START
# 115 高 gāo high
# ENTRY END
#
#
# ENTRY START
# 116 高兴 gāoxìng happy
# ENTRY END
#
#
# ENTRY START
# 117 告诉 gàosu tell
# ENTRY END
#
#
# ENTRY START
# 118 哥哥｜哥 gē ge ｜ gē elder brother
# ENTRY END
#
#
# ENTRY START
# 119 歌 gē song
# ENTRY END
#
#
# ENTRY START
# 120 个 gè individual
# ENTRY END
#
#
# ENTRY START
# 121 给 gěi give
# ENTRY END
#
#
# ENTRY START
# 122 跟 gēn with
# ENTRY END
#
#
# ENTRY START
# 123 工人 gōngrén Worker
# ENTRY END
#
#
# ENTRY START
# 124 工作 gōngzuò work
# ENTRY END
#
#
# ENTRY START
# 125 关（动） guān shut; close; turn off
# ENTRY END
#
#
# ENTRY START
# 126 关上 guān shàng close;shut to; turn off
# ENTRY END
#
#
# ENTRY START
# 127 贵 guì noble
# ENTRY END
#
#
# ENTRY START
# 128 国 guó country; state; nation
# ENTRY END
#
#
# ENTRY START
#
# 7
# ENTRY END
#
#
# ENTRY START
#  130 国外 guó wài foreign; oversea; abroad
# ENTRY END
#
#
# ENTRY START
# 131 过 guò pass
# ENTRY END
#
#
# ENTRY START
# 132 还 hái also; still; yet
# ENTRY END
#
#
# ENTRY START
# 133 还是 háishi still
# ENTRY END
#
#
# ENTRY START
# 134 还有 hái yǒu also; in addition; besides
# ENTRY END
#
#
# ENTRY START
# 135 孩子 háizi Children
# ENTRY END
#
#
# ENTRY START
# 136 汉语 hànyǔ Chinese
# ENTRY END
#
#
# ENTRY START
# 137 汉字 hàn zì Chinese character
# ENTRY END
#
#
# ENTRY START
# 138 好（形） hǎo good
# ENTRY END
#
#
# ENTRY START
# 139 好吃 hǎochī Yummy
# ENTRY END
#
#
# ENTRY START
# 140 好看 hǎo kàn good looking
# ENTRY END
#
#
# ENTRY START
# 141 好听 hǎo tīng pleasant to hear
# ENTRY END
#
#
# ENTRY START
# 142 好玩儿 hǎo wánr fun; interesting
# ENTRY END
#
#
# ENTRY START
# 143 号 hào Number/date
# ENTRY END
#
#
# ENTRY START
# 144 喝 hē drink
# ENTRY END
#
#
# ENTRY START
# 145 和 hé and
# ENTRY END
#
#
# ENTRY START
# 146 很 hěn very
# ENTRY END
#
#
# ENTRY START
# 147 后 hòu back; behind; after; later
# ENTRY END
#
#
# ENTRY START
# 148 后边 hòu biān behind; back
# ENTRY END
#
#
# ENTRY START
# 149 后天 hòu tiān day after tomorrow
# ENTRY END
#
#
# ENTRY START
# 150 花（名） huā flower
# ENTRY END
#
#
# ENTRY START
#
# 8
# ENTRY END
#
#
# ENTRY START
#  152 坏 huài bad
# ENTRY END
#
#
# ENTRY START
# 153 还 huán return; pay back
# ENTRY END
#
#
# ENTRY START
# 154 回（动） huí go back; return
# ENTRY END
#
#
# ENTRY START
# 155 回答 huídá Answer
# ENTRY END
#
#
# ENTRY START
# 156 回到 huí dào back to
# ENTRY END
#
#
# ENTRY START
# 157 回家 huí jiā go home; return home
# ENTRY END
#
#
# ENTRY START
# 158 回来 huí lái come back; return
# ENTRY END
#
#
# ENTRY START
# 159 回去 huí qù go back
# ENTRY END
#
#
# ENTRY START
# 160 会（动） huì can; be able to
# ENTRY END
#
#
# ENTRY START
# 161 火车 huǒ chē train
# ENTRY END
#
#
# ENTRY START
# 162 机场 jīchǎng Airport
# ENTRY END
#
#
# ENTRY START
# 163 机票 jī piào air ticket
# ENTRY END
#
#
# ENTRY START
# 164 鸡蛋 jīdàn Egg
# ENTRY END
#
#
# ENTRY START
# 165 几 jǐ several
# ENTRY END
#
#
# ENTRY START
# 166 记 jì remember
# ENTRY END
#
#
# ENTRY START
# 167 记得 jìdé remember
# ENTRY END
#
#
# ENTRY START
# 168 记住 jì zhù remember; keep in mind
# ENTRY END
#
#
# ENTRY START
# 169 家 jiā home
# ENTRY END
#
#
# ENTRY START
# 170 家里 jiā lǐ In the home
# ENTRY END
#
#
# ENTRY START
# 171 家人 jiā rén family
# ENTRY END
#
#
# ENTRY START
# 172 间 jiān between; measure word for rooms
# ENTRY END
#
#
# ENTRY START
#
# 9
# ENTRY END
#
#
# ENTRY START
#  174 见面 jiànmiàn meet
# ENTRY END
#
#
# ENTRY START
# 175 教 jiāo teach
# ENTRY END
#
#
# ENTRY START
# 176 叫（动） jiào call; be called
# ENTRY END
#
#
# ENTRY START
# 177 教学楼 jiào xué lóu teaching building
# ENTRY END
#
#
# ENTRY START
# 178 姐姐｜姐 jiě jie ｜ jiě elder sister
# ENTRY END
#
#
# ENTRY START
# 179 介绍 jièshào introduce
# ENTRY END
#
#
# ENTRY START
# 180 今年 jīn nián this year
# ENTRY END
#
#
# ENTRY START
# 181 今天 jīntiān Today
# ENTRY END
#
#
# ENTRY START
# 182 进 jìn enter
# ENTRY END
#
#
# ENTRY START
# 183 进来 jìn lái come in
# ENTRY END
#
#
# ENTRY START
# 184 进去 jìn qù go in
# ENTRY END
#
#
# ENTRY START
# 185 九 jiǔ Nine
# ENTRY END
#
#
# ENTRY START
# 186 就 jiù as soon as; right away; then
# ENTRY END
#
#
# ENTRY START
# 187 觉得 juéde Think
# ENTRY END
#
#
# ENTRY START
# 188 开 kāi open
# ENTRY END
#
#
# ENTRY START
# 189 开车 kāi chē drive; drive a car
# ENTRY END
#
#
# ENTRY START
# 190 开会 kāi huì have a meeting
# ENTRY END
#
#
# ENTRY START
# 191 开玩笑 kāiwánxiào Make fun of
# ENTRY END
#
#
# ENTRY START
# 192 看 kàn see
# ENTRY END
#
#
# ENTRY START
# 193 看病 kàn bìng see a doctor
# ENTRY END
#
#
# ENTRY START
# 194 看到 kàn dào see
# ENTRY END
#
#
# ENTRY START
#
# 10
# ENTRY END
#
#
# ENTRY START
#  196 考 kǎo test; examine
# ENTRY END
#
#
# ENTRY START
# 197 考试 kǎoshì Examination
# ENTRY END
#
#
# ENTRY START
# 198 渴 kě thirsty
# ENTRY END
#
#
# ENTRY START
# 199 课 kè course
# ENTRY END
#
#
# ENTRY START
# 200 课本 kè běn textbook
# ENTRY END
#
#
# ENTRY START
# 201 课文 kè wén text
# ENTRY END
#
#
# ENTRY START
# 202 口 kǒu mouth
# ENTRY END
#
#
# ENTRY START
# 203 块 kuài block
# ENTRY END
#
#
# ENTRY START
# 204 快 kuài fast
# ENTRY END
#
#
# ENTRY START
# 205 来 lái come
# ENTRY END
#
#
# ENTRY START
# 206 来到 lái dào come; arrive
# ENTRY END
#
#
# ENTRY START
# 207 老（形） lǎo old; aged
# ENTRY END
#
#
# ENTRY START
# 208 老人 lǎo rén old people; the aged
# ENTRY END
#
#
# ENTRY START
# 209 老师 lǎoshī Teacher
# ENTRY END
#
#
# ENTRY START
# 210 了 le past tense marker
# ENTRY END
#
#
# ENTRY START
# 211 累 lèi tired
# ENTRY END
#
#
# ENTRY START
# 212 冷 lěng cold
# ENTRY END
#
#
# ENTRY START
# 213 里 lǐ in
# ENTRY END
#
#
# ENTRY START
# 214 里边 lǐ biān inside
# ENTRY END
#
#
# ENTRY START
# 215 两（数） liǎng two
# ENTRY END
#
#
# ENTRY START
# 216 零｜〇 líng ｜ líng zero
# ENTRY END
#
#
# ENTRY START
#
# 11
# ENTRY END
#
#
# ENTRY START
#  218 楼 lóu floor
# ENTRY END
#
#
# ENTRY START
# 219 楼上 lóu shàng upstairs
# ENTRY END
#
#
# ENTRY START
# 220 楼下 lóu xià downstairs
# ENTRY END
#
#
# ENTRY START
# 221 路 lù road
# ENTRY END
#
#
# ENTRY START
# 222 路口 lù kǒu intersection; crossing
# ENTRY END
#
#
# ENTRY START
# 223 路上 lù shàng on the road
# ENTRY END
#
#
# ENTRY START
# 224 妈妈｜妈 mā ma ｜
# mā mom; mother
# ENTRY END
#
#
# ENTRY START
# 225 马路 mǎ lù road; street
# ENTRY END
#
#
# ENTRY START
# 226 马上 mǎshàng Right off
# ENTRY END
#
#
# ENTRY START
# 227 吗 ma auxiliary word
# ENTRY END
#
#
# ENTRY START
# 228 买 mǎi buy
# ENTRY END
#
#
# ENTRY START
# 229 慢 màn slow
# ENTRY END
#
#
# ENTRY START
# 230 忙 máng busy
# ENTRY END
#
#
# ENTRY START
# 231 毛（量） máo a fractional unit of money in China
# (measure word)
# ENTRY END
#
#
# ENTRY START
# 232 没 méi no
# ENTRY END
#
#
# ENTRY START
# 233 没关系 méiguānxi No problem
# ENTRY END
#
#
# ENTRY START
# 234 没什么 méi shén me It's nothing
# ENTRY END
#
#
# ENTRY START
# 235 没事儿 méi shìr It's okay
# ENTRY END
#
#
# ENTRY START
# 236 没有 méi yǒu have not; no
# ENTRY END
#
#
# ENTRY START
#
# 12
#  mèi
# ENTRY END
#
#
# ENTRY START
# 238 门 mén door
# ENTRY END
#
#
# ENTRY START
# 239 门口 mén kǒu doorway
# ENTRY END
#
#
# ENTRY START
# 240 门票 mén piào tickets
# ENTRY END
#
#
# ENTRY START
# 241 们（朋友们） men （ péng
# yǒu men ） plural marker for pronouns and a few
# animate nouns (friends)
# ENTRY END
#
#
# ENTRY START
# 242 米饭 mǐfàn Steamed Rice
# ENTRY END
#
#
# ENTRY START
# 243 面包 miànbāo Bread
# ENTRY END
#
#
# ENTRY START
# 244 面条儿 miàn tiáor noodles
# ENTRY END
#
#
# ENTRY START
# 245 名字 míngzi Name
# ENTRY END
#
#
# ENTRY START
# 246 明白 míngbai clear
# ENTRY END
#
#
# ENTRY START
# 247 明年 míng nián next year
# ENTRY END
#
#
# ENTRY START
# 248 明天 míngtiān Tomorrow
# ENTRY END
#
#
# ENTRY START
# 249 拿 ná take
# ENTRY END
#
#
# ENTRY START
# 250 哪 nǎ which
# ENTRY END
#
#
# ENTRY START
# 251 哪里 nǎ lǐ where
# ENTRY END
#
#
# ENTRY START
# 252 哪儿 nǎr where
# ENTRY END
#
#
# ENTRY START
# 253 哪些 nǎ xiē which
# ENTRY END
#
#
# ENTRY START
# 254 那（代） nà that
# ENTRY END
#
#
# ENTRY START
# 255 那边 nà biān there
# ENTRY END
#
#
# ENTRY START
# 256 那里 nà lǐ there
# ENTRY END
#
#
# ENTRY START
#
# 13
# ENTRY END
#
#
# ENTRY START
#  258 那些 nà xiē those
# ENTRY END
#
#
# ENTRY START
# 259 奶 nǎi milk
# ENTRY END
#
#
# ENTRY START
# 260 奶奶 nǎinai grandma
# ENTRY END
#
#
# ENTRY START
# 261 男 nán Man
# ENTRY END
#
#
# ENTRY START
# 262 男孩儿 nán háir boy
# ENTRY END
#
#
# ENTRY START
# 263 男朋友 nán péng yǒu boyfriend
# ENTRY END
#
#
# ENTRY START
# 264 男人 nán ren man
# ENTRY END
#
#
# ENTRY START
# 265 男生 nán shēng boy
# ENTRY END
#
#
# ENTRY START
# 266 南 nán south
# ENTRY END
#
#
# ENTRY START
# 267 南边 nán biān south; south side
# ENTRY END
#
#
# ENTRY START
# 268 难 nán hard, difficult
# ENTRY END
#
#
# ENTRY START
# 269 呢 ne auxiliary word
# ENTRY END
#
#
# ENTRY START
# 270 能 néng can
# ENTRY END
#
#
# ENTRY START
# 271 你 nǐ you
# ENTRY END
#
#
# ENTRY START
# 272 你们 nǐ men you
# ENTRY END
#
#
# ENTRY START
# 273 年 nián year
# ENTRY END
#
#
# ENTRY START
# 274 您 nín you
# ENTRY END
#
#
# ENTRY START
# 275 牛奶 niúnǎi milk
# ENTRY END
#
#
# ENTRY START
# 276 女 nǚ woman
# ENTRY END
#
#
# ENTRY START
# 277 女儿 nǚ'ér daughter
# ENTRY END
#
#
# ENTRY START
# 278 女孩儿 nǚ háir girl
# ENTRY END
#
#
# ENTRY START
#
# 14
# ENTRY END
#
#
# ENTRY START
#  280 女人 nǚ ren woman
# ENTRY END
#
#
# ENTRY START
# 281 女生 nǚ shēng girl
# ENTRY END
#
#
# ENTRY START
# 282 旁边 pángbiān Side
# ENTRY END
#
#
# ENTRY START
# 283 跑 pǎo run
# ENTRY END
#
#
# ENTRY START
# 284 朋友 péngyou Friend
# ENTRY END
#
#
# ENTRY START
# 285 票 piào ticket
# ENTRY END
#
#
# ENTRY START
# 286 七 qī Seven
# ENTRY END
#
#
# ENTRY START
# 287 起 qǐ get up; start; rise
# ENTRY END
#
#
# ENTRY START
# 288 起床 qǐchuáng Get up
# ENTRY END
#
#
# ENTRY START
# 289 起来 qǐlái get up
# ENTRY END
#
#
# ENTRY START
# 290 汽车 qì chē car
# ENTRY END
#
#
# ENTRY START
# 291 前 qián front
# ENTRY END
#
#
# ENTRY START
# 292 前边 qián biān in front
# ENTRY END
#
#
# ENTRY START
# 293 前天 qián tiān the day before yesterday
# ENTRY END
#
#
# ENTRY START
# 294 钱 qián money
# ENTRY END
#
#
# ENTRY START
# 295 钱包 qián bāo wallet
# ENTRY END
#
#
# ENTRY START
# 296 请 qǐng please
# ENTRY END
#
#
# ENTRY START
# 297 请假 qǐngjià ask for leave
# ENTRY END
#
#
# ENTRY START
# 298 请进 qǐng jìn please come in
# ENTRY END
#
#
# ENTRY START
# 299 请问 qǐng wèn excuse me
# ENTRY END
#
#
# ENTRY START
# 300 请坐 qǐng zuò please have a seat
# ENTRY END
#
#
# ENTRY START
#
# 15
# ENTRY END
#
#
# ENTRY START
#  302 去 qù go
# ENTRY END
#
#
# ENTRY START
# 303 去年 qùnián Last year
# ENTRY END
#
#
# ENTRY START
# 304 热 rè heat
# ENTRY END
#
#
# ENTRY START
# 305 人 rén people
# ENTRY END
#
#
# ENTRY START
# 306 认识 rènshi know
# ENTRY END
#
#
# ENTRY START
# 307 认真 rènzhēn earnest
# ENTRY END
#
#
# ENTRY START
# 308 日 rì date
# ENTRY END
#
#
# ENTRY START
# 309 日期 rìqī Date
# ENTRY END
#
#
# ENTRY START
# 310 肉 ròu meat
# ENTRY END
#
#
# ENTRY START
# 311 三 sān Three
# ENTRY END
#
#
# ENTRY START
# 312 山 shān mountain
# ENTRY END
#
#
# ENTRY START
# 313 商场 shāng chǎng mall; shopping mall
# ENTRY END
#
#
# ENTRY START
# 314 商店 shāngdiàn Shop
# ENTRY END
#
#
# ENTRY START
# 315 上 shàng upper
# ENTRY END
#
#
# ENTRY START
# 316 上班 shàngbān go to work
# ENTRY END
#
#
# ENTRY START
# 317 上边 shàng biān above; on
# ENTRY END
#
#
# ENTRY START
# 318 上车 shàng chē get on
# ENTRY END
#
#
# ENTRY START
# 319 上次 shàng cì last time
# ENTRY END
#
#
# ENTRY START
# 320 上课 shàng kè attend class; have a class
# ENTRY END
#
#
# ENTRY START
# 321 上网 shàngwǎng Surf the Internet
# ENTRY END
#
#
# ENTRY START
# 322 上午 shàngwǔ morning
# ENTRY END
#
#
# ENTRY START
#
# 16
# ENTRY END
#
#
# ENTRY START
#  324 少 shǎo less
# ENTRY END
#
#
# ENTRY START
# 325 谁 shéi who
# ENTRY END
#
#
# ENTRY START
# 326 身上 shēn shàng body; on one's body
# ENTRY END
#
#
# ENTRY START
# 327 身体 shēntǐ body
# ENTRY END
#
#
# ENTRY START
# 328 什么 shénme What
# ENTRY END
#
#
# ENTRY START
# 329 生病 shēngbìng Fall ill
# ENTRY END
#
#
# ENTRY START
# 330 生气 shēngqì get angry
# ENTRY END
#
#
# ENTRY START
# 331 生日 shēngrì Birthday
# ENTRY END
#
#
# ENTRY START
# 332 十 shí Ten
# ENTRY END
#
#
# ENTRY START
# 333 时候 shíhou time
# ENTRY END
#
#
# ENTRY START
# 334 时间 shíjiān time
# ENTRY END
#
#
# ENTRY START
# 335 事 shì thing
# ENTRY END
#
#
# ENTRY START
# 336 试 shì try
# ENTRY END
#
#
# ENTRY START
# 337 是 shì yes
# ENTRY END
#
#
# ENTRY START
# 338 是不是 shì bú shì isn't it?
# ENTRY END
#
#
# ENTRY START
# 339 手 shǒu hand
# ENTRY END
#
#
# ENTRY START
# 340 手机 shǒujī Mobile phone
# ENTRY END
#
#
# ENTRY START
# 341 书 shū book
# ENTRY END
#
#
# ENTRY START
# 342 书包 shū bāo school bag
# ENTRY END
#
#
# ENTRY START
# 343 书店 shū diàn bookstore
# ENTRY END
#
#
# ENTRY START
# 344 树 shù tree
# ENTRY END
#
#
# ENTRY START
#
# 17
# ENTRY END
#
#
# ENTRY START
#  346 水果 shuǐguǒ Fruits
# ENTRY END
#
#
# ENTRY START
# 347 睡 shuì sleep
# ENTRY END
#
#
# ENTRY START
# 348 睡觉 shuìjiào sleep
# ENTRY END
#
#
# ENTRY START
# 349 说 shuō speak
# ENTRY END
#
#
# ENTRY START
# 350 说话 shuōhuà talk
# ENTRY END
#
#
# ENTRY START
# 351 四 sì Four
# ENTRY END
#
#
# ENTRY START
# 352 送 sòng give
# ENTRY END
#
#
# ENTRY START
# 353 岁 suì year, age
# ENTRY END
#
#
# ENTRY START
# 354 他 tā he
# ENTRY END
#
#
# ENTRY START
# 355 他们 tā men they
# ENTRY END
#
#
# ENTRY START
# 356 她 tā she
# ENTRY END
#
#
# ENTRY START
# 357 她们 tā men they
# ENTRY END
#
#
# ENTRY START
# 358 太 tài too
# ENTRY END
#
#
# ENTRY START
# 359 天 tiān day
# ENTRY END
#
#
# ENTRY START
# 360 天气 tiānqì weather
# ENTRY END
#
#
# ENTRY START
# 361 听 tīng hear
# ENTRY END
#
#
# ENTRY START
# 362 听到 tīng dào hear
# ENTRY END
#
#
# ENTRY START
# 363 听见 tīng jiàn hear
# ENTRY END
#
#
# ENTRY START
# 364 听写 tīng xiě dictation; dictate
# ENTRY END
#
#
# ENTRY START
# 365 同学 tóngxué Classmate
# ENTRY END
#
#
# ENTRY START
# 366 图书馆 túshūguǎn Library
# ENTRY END
#
#
# ENTRY START
#
# 18
# ENTRY END
#
#
# ENTRY START
#  368 外边 wài biān outside
# ENTRY END
#
#
# ENTRY START
# 369 外国 wài guó foreign country
# ENTRY END
#
#
# ENTRY START
# 370 外语 wài yǔ foreign language
# ENTRY END
#
#
# ENTRY START
# 371 玩儿 wánr play
# ENTRY END
#
#
# ENTRY START
# 372 晚 wǎn late
# ENTRY END
#
#
# ENTRY START
# 373 晚饭 wǎn fàn dinner
# ENTRY END
#
#
# ENTRY START
# 374 晚上 wǎnshang Night
# ENTRY END
#
#
# ENTRY START
# 375 网上 wǎng shàng online
# ENTRY END
#
#
# ENTRY START
# 376 网友 wǎng yǒu net friend
# ENTRY END
#
#
# ENTRY START
# 377 忘 wàng forget
# ENTRY END
#
#
# ENTRY START
# 378 忘记 wàngjì forget
# ENTRY END
#
#
# ENTRY START
# 379 问 wèn ask
# ENTRY END
#
#
# ENTRY START
# 380 我 wǒ I
# ENTRY END
#
#
# ENTRY START
# 381 我们 wǒmen We
# ENTRY END
#
#
# ENTRY START
# 382 五 wǔ Five
# ENTRY END
#
#
# ENTRY START
# 383 午饭 wǔ fàn lunch
# ENTRY END
#
#
# ENTRY START
# 384 西 xī west
# ENTRY END
#
#
# ENTRY START
# 385 西边 xī biān west; west side
# ENTRY END
#
#
# ENTRY START
# 386 洗 xǐ wash
# ENTRY END
#
#
# ENTRY START
# 387 洗手间 xǐshǒujiān Restroom
# ENTRY END
#
#
# ENTRY START
# 388 喜欢 xǐhuan like
# ENTRY END
#
#
# ENTRY START
#
# 19
# ENTRY END
#
#
# ENTRY START
#  390 下班 xià bān get off work
# ENTRY END
#
#
# ENTRY START
# 391 下边 xià biān below; under
# ENTRY END
#
#
# ENTRY START
# 392 下车 xià chē get off
# ENTRY END
#
#
# ENTRY START
# 393 下次 xià cì next time
# ENTRY END
#
#
# ENTRY START
# 394 下课 xià kè finish class
# ENTRY END
#
#
# ENTRY START
# 395 下午 xiàwǔ Afternoon
# ENTRY END
#
#
# ENTRY START
# 396 下雨 xiàyǔ rain
# ENTRY END
#
#
# ENTRY START
# 397 先 xiān before
# ENTRY END
#
#
# ENTRY START
# 398 先生 xiānsheng Sir
# ENTRY END
#
#
# ENTRY START
# 399 现在 xiànzài Now
# ENTRY END
#
#
# ENTRY START
# 400 想 xiǎng think
# ENTRY END
#
#
# ENTRY START
# 401 小 xiǎo Small
# ENTRY END
#
#
# ENTRY START
# 402 小孩儿 xiǎo háir child; kid
# ENTRY END
#
#
# ENTRY START
# 403 小姐 xiǎojiě Miss
# ENTRY END
#
#
# ENTRY START
# 404 小朋友 xiǎo péng yǒu child; kid
# ENTRY END
#
#
# ENTRY START
# 405 小时 xiǎoshí hour
# ENTRY END
#
#
# ENTRY START
# 406 小学 xiǎo xué primary school; elementary schoo
# ENTRY END
#
#
# ENTRY START
# 407 小学生 xiǎo xué
# shēng elementary school student
# ENTRY END
#
#
# ENTRY START
# 408 笑 xiào laugh
# ENTRY END
#
#
# ENTRY START
# 409 写 xiě write
# ENTRY END
#
#
# ENTRY START
#
# 20
# ENTRY END
#
#
# ENTRY START
#  411 新 xīn new
# ENTRY END
#
#
# ENTRY START
# 412 新年 xīn nián New Year
# ENTRY END
#
#
# ENTRY START
# 413 星期 xīngqī week
# ENTRY END
#
#
# ENTRY START
# 414 星期日 xīng qī rì Sunday
# ENTRY END
#
#
# ENTRY START
# 415 星期天 xīng qī tiān Sunday
# ENTRY END
#
#
# ENTRY START
# 416 行 xíng That's ok
# ENTRY END
#
#
# ENTRY START
# 417 休息 xiūxi Rest
# ENTRY END
#
#
# ENTRY START
# 418 学 xué learn; study
# ENTRY END
#
#
# ENTRY START
# 419 学生 xuésheng Student
# ENTRY END
#
#
# ENTRY START
# 420 学习 xuéxí Study
# ENTRY END
#
#
# ENTRY START
# 421 学校 xuéxiào School
# ENTRY END
#
#
# ENTRY START
# 422 学院 xué yuàn college; academy
# ENTRY END
#
#
# ENTRY START
# 423 要（动） yào want
# ENTRY END
#
#
# ENTRY START
# 424 爷爷 yéye grandpa
# ENTRY END
#
#
# ENTRY START
# 425 也 yě also
# ENTRY END
#
#
# ENTRY START
# 426 页 yè page
# ENTRY END
#
#
# ENTRY START
# 427 一 yī One
# ENTRY END
#
#
# ENTRY START
# 428 衣服 yīfu clothes
# ENTRY END
#
#
# ENTRY START
# 429 医生 yīshēng Doctor
# ENTRY END
#
#
# ENTRY START
# 430 医院 yīyuàn Hospital
# ENTRY END
#
#
# ENTRY START
# 431 一半 yí bàn half
# ENTRY END
#
#
# ENTRY START
#
# 21
# ENTRY END
#
#
# ENTRY START
#  433 一块儿 yí kuàir together
# ENTRY END
#
#
# ENTRY START
# 434 一下儿 yí xiàr a little bit
# ENTRY END
#
#
# ENTRY START
# 435 一样 yíyàng equally
# ENTRY END
#
#
# ENTRY START
# 436 一边 yìbiān One side
# ENTRY END
#
#
# ENTRY START
# 437 一点儿 yīdiǎnr a little bit
# ENTRY END
#
#
# ENTRY START
# 438 一起 yìqǐ together
# ENTRY END
#
#
# ENTRY START
# 439 一些 yì xiē some
# ENTRY END
#
#
# ENTRY START
# 440 用 yòng use
# ENTRY END
#
#
# ENTRY START
# 441 有 yǒu have
# ENTRY END
#
#
# ENTRY START
# 442 有的 yǒu de some
# ENTRY END
#
#
# ENTRY START
# 443 有名 yǒumíng Famous
# ENTRY END
#
#
# ENTRY START
# 444 有时候｜有时 yǒu shí
# hòu ｜ yǒu s
# hí sometimes
# ENTRY END
#
#
# ENTRY START
# 445 有（一）些 yǒu （ yì ）
# xiē some
# ENTRY END
#
#
# ENTRY START
# 446 有用 yǒu yòng useful
# ENTRY END
#
#
# ENTRY START
# 447 右 yòu right
# ENTRY END
#
#
# ENTRY START
# 448 右边 yòubian Right
# ENTRY END
#
#
# ENTRY START
# 449 雨 yǔ rain
# ENTRY END
#
#
# ENTRY START
# 450 元 yuán element; Yuan
# ENTRY END
#
#
# ENTRY START
#
# 22
# ENTRY END
#
#
# ENTRY START
#  452 月 yuè month
# ENTRY END
#
#
# ENTRY START
# 453 再 zài again
# ENTRY END
#
#
# ENTRY START
# 454 再见 zàijiàn Bye
# ENTRY END
#
#
# ENTRY START
# 455 在 zài stay; in process of
# ENTRY END
#
#
# ENTRY START
# 456 在家 zài jiā at home
# ENTRY END
#
#
# ENTRY START
# 457 早 zǎo early
# ENTRY END
#
#
# ENTRY START
# 458 早饭 zǎo fàn breakfast
# ENTRY END
#
#
# ENTRY START
# 459 早上 zǎoshang Morning
# ENTRY END
#
#
# ENTRY START
# 460 怎么 zěnme How
# ENTRY END
#
#
# ENTRY START
# 461 站（名） zhàn station
# ENTRY END
#
#
# ENTRY START
# 462 找 zhǎo look for
# ENTRY END
#
#
# ENTRY START
# 463 找到 zhǎo dào find
# ENTRY END
#
#
# ENTRY START
# 464 这 zhè Here (here)
# ENTRY END
#
#
# ENTRY START
# 465 这边 zhè biān here
# ENTRY END
#
#
# ENTRY START
# 466 这里 zhè lǐ here
# ENTRY END
#
#
# ENTRY START
# 467 这儿 zhèr here
# ENTRY END
#
#
# ENTRY START
# 468 这些 zhè xiē these
# ENTRY END
#
#
# ENTRY START
# 469 着 zhe in process of
# ENTRY END
#
#
# ENTRY START
# 470 真 zhēn really
# ENTRY END
#
#
# ENTRY START
# 471 真的 zhēn de really
# ENTRY END
#
#
# ENTRY START
# 472 正（副） zhèng just; exactly
# ENTRY END
#
#
# ENTRY START
#
# 23
# ENTRY END
#
#
# ENTRY START
#  474 知道 zhīdào know
# ENTRY END
#
#
# ENTRY START
# 475 知识 zhīshi knowledge
# ENTRY END
#
#
# ENTRY START
# 476 中 zhōng middle; in
# ENTRY END
#
#
# ENTRY START
# 477 中国 zhōngguó China
# ENTRY END
#
#
# ENTRY START
# 478 中间 zhōngjiān Middle
# ENTRY END
#
#
# ENTRY START
# 479 中文 zhōngwén Chinese
# ENTRY END
#
#
# ENTRY START
# 480 中午 zhōngwǔ Noon
# ENTRY END
#
#
# ENTRY START
# 481 中学 zhōng xué middle school
# ENTRY END
#
#
# ENTRY START
# 482 中学生 zhōng xué
# shēng middle School student
# ENTRY END
#
#
# ENTRY START
# 483 重 zhòng heavy
# ENTRY END
#
#
# ENTRY START
# 484 重要 zhòngyào important
# ENTRY END
#
#
# ENTRY START
# 485 住 zhù live
# ENTRY END
#
#
# ENTRY START
# 486 准备 zhǔnbèi Get ready
# ENTRY END
#
#
# ENTRY START
# 487 桌子 zhuōzi Table
# ENTRY END
#
#
# ENTRY START
# 488 字 zì word, character
# ENTRY END
#
#
# ENTRY START
# 489 子（桌子） zi （ zhuō zi
# ） noun suffix (table)
# ENTRY END
#
#
# ENTRY START
# 490 走 zǒu go, walk
# ENTRY END
#
#
# ENTRY START
# 491 走路 zǒu lù walk
# ENTRY END
#
#
# ENTRY START
# 492 最 zuì most
# ENTRY END
#
#
# ENTRY START
#
# 24
# ENTRY END
#
#
# ENTRY START
#  494 最后 zuìhòu Last
# ENTRY END
#
#
# ENTRY START
# 495 昨天 zuótiān Yesterday
# ENTRY END
#
#
# ENTRY START
# 496 左 zuǒ left
# ENTRY END
#
#
# ENTRY START
# 497 左边 zuǒbian left
# ENTRY END
#
#
# ENTRY START
# 498 坐 zuò sit
# ENTRY END
#
#
# ENTRY START
# 499 坐下 zuò xià sit down
# ENTRY END
#
#
# New-HSK-2-Word-List 38
# ENTRY START
#
# 1
#  No Chinese Pinyin English
# ENTRY END
#
#
# ENTRY START
# 1 啊 a auxiliary word
# ENTRY END
#
#
# ENTRY START
# 2 爱情 àiqíng Love
# ENTRY END
#
#
# ENTRY START
# 3 爱人 ài rén lover
# ENTRY END
#
#
# ENTRY START
# 4 安静 ānjìng Be quiet
# ENTRY END
#
#
# ENTRY START
# 5 安全 ānquán security
# ENTRY END
#
#
# ENTRY START
# 6 白色 bái sè white
# ENTRY END
#
#
# ENTRY START
# 7 班长 bān zhǎng monitor; squad leader
# ENTRY END
#
#
# ENTRY START
# 8 办 bàn do
# ENTRY END
#
#
# ENTRY START
# 9 办法 bànfǎ Way
# ENTRY END
#
#
# ENTRY START
# 10 办公室 bàngōngshì Office
# ENTRY END
#
#
# ENTRY START
# 11 半夜 bàn yè midnight
# ENTRY END
#
#
# ENTRY START
# 12 帮助 bāngzhù Help
# ENTRY END
#
#
# ENTRY START
# 13 饱 bǎo full
# ENTRY END
#
#
# ENTRY START
# 14 报名 bàomíng sign up
# ENTRY END
#
#
# ENTRY START
# 15 报纸 bàozhǐ Newspaper
# ENTRY END
#
#
# ENTRY START
# 16 北方 běifāng north
# ENTRY END
#
#
# ENTRY START
# 17 背（动） bēi carry on the back; shoulder
# ENTRY END
#
#
# ENTRY START
# 18 比如 bǐrú such as
# ENTRY END
#
#
# ENTRY START
# 19 比如说 bǐ rú shuō for example
# ENTRY END
#
#
# ENTRY START
# 20 笔 bǐ pen
# ENTRY END
#
#
# ENTRY START
#
# 2
# ENTRY END
#
#
# ENTRY START
#  22 笔记本 bǐjìběn Notebook
# ENTRY END
#
#
# ENTRY START
# 23 必须 bìxū Must
# ENTRY END
#
#
# ENTRY START
# 24 边 biān side
# ENTRY END
#
#
# ENTRY START
# 25 变 biàn change
# ENTRY END
#
#
# ENTRY START
# 26 变成 biàn chéng become; change into
# ENTRY END
#
#
# ENTRY START
# 27 遍 biàn Times
# ENTRY END
#
#
# ENTRY START
# 28 表 biǎo watch
# ENTRY END
#
#
# ENTRY START
# 29 表示 biǎoshì Express
# ENTRY END
#
#
# ENTRY START
# 30 不错 bú cuò not bad; pretty good
# ENTRY END
#
#
# ENTRY START
# 31 不但 bú dàn not only
# ENTRY END
#
#
# ENTRY START
# 32 不够 bú gòu not enough
# ENTRY END
#
#
# ENTRY START
# 33 不过 búguò However
# ENTRY END
#
#
# ENTRY START
# 34 不太 bú tài not too; not very much
# ENTRY END
#
#
# ENTRY START
# 35 不要 bú yào don't
# ENTRY END
#
#
# ENTRY START
# 36 不好意思 bù hǎo yì sī sorry; feel embarrassed
# ENTRY END
#
#
# ENTRY START
# 37 不久 bù jiǔ soon
# ENTRY END
#
#
# ENTRY START
# 38 不满 bù mǎn dissatisfied
# ENTRY END
#
#
# ENTRY START
# 39 不如 bùrú not as good as
# ENTRY END
#
#
# ENTRY START
# 40 不少 bù shǎo not a few; a lot
# ENTRY END
#
#
# ENTRY START
# 41 不同 bù tóng different
# ENTRY END
#
#
# ENTRY START
# 42 不行 bù xíng no way; be out of the question
# ENTRY END
#
#
# ENTRY START
#
# 3
# ENTRY END
#
#
# ENTRY START
#  44 不一会儿 bù yī huìr in a moment; in a little while;
# soon
# ENTRY END
#
#
# ENTRY START
# 45 部分 bùfen Part
# ENTRY END
#
#
# ENTRY START
# 46 才（副） cái only; just
# ENTRY END
#
#
# ENTRY START
# 47 菜单 càidān menu
# ENTRY END
#
#
# ENTRY START
# 48 参观 cānguān visit
# ENTRY END
#
#
# ENTRY START
# 49 参加 cānjiā participate in
# ENTRY END
#
#
# ENTRY START
# 50 草 cǎo grass
# ENTRY END
#
#
# ENTRY START
# 51 草地 cǎo dì grass; lawn
# ENTRY END
#
#
# ENTRY START
# 52 层 céng layer
# ENTRY END
#
#
# ENTRY START
# 53 查 chá search; check
# ENTRY END
#
#
# ENTRY START
# 54 差不多 chàbuduō Almost
# ENTRY END
#
#
# ENTRY START
# 55 长 cháng long
# ENTRY END
#
#
# ENTRY START
# 56 常见 cháng jiàn common
# ENTRY END
#
#
# ENTRY START
# 57 常用 cháng yòng in common use
# ENTRY END
#
#
# ENTRY START
# 58 场 chǎng site
# ENTRY END
#
#
# ENTRY START
# 59 超过 chāoguò Exceed
# ENTRY END
#
#
# ENTRY START
# 60 超市 chāoshì Supermarket
# ENTRY END
#
#
# ENTRY START
# 61 车辆 chē liàng car; vehicle
# ENTRY END
#
#
# ENTRY START
# 62 称¹（动） chēng call; say
# ENTRY END
#
#
# ENTRY START
# 63 成（动） chéng become; finish
# ENTRY END
#
#
# ENTRY START
#
# 4
# ENTRY END
#
#
# ENTRY START
#  65 成为 chéngwéi Become
# ENTRY END
#
#
# ENTRY START
# 66 重复 chóngfù repeat
# ENTRY END
#
#
# ENTRY START
# 67 重新 chóngxīn again
# ENTRY END
#
#
# ENTRY START
# 68 出发 chūfā Set out
# ENTRY END
#
#
# ENTRY START
# 69 出国 chū guó go abroad
# ENTRY END
#
#
# ENTRY START
# 70 出口（名） chū kǒu export
# ENTRY END
#
#
# ENTRY START
# 71 出门 chū mén go out
# ENTRY END
#
#
# ENTRY START
# 72 出生 chūshēng Birth
# ENTRY END
#
#
# ENTRY START
# 73 出现 chūxiàn Appear
# ENTRY END
#
#
# ENTRY START
# 74 出院 chū yuàn discharged; leave hospital
# ENTRY END
#
#
# ENTRY START
# 75 出租 chū zū rent
# ENTRY END
#
#
# ENTRY START
# 76 出租车 chūzūchē Taxi
# ENTRY END
#
#
# ENTRY START
# 77 船 chuán ship
# ENTRY END
#
#
# ENTRY START
# 78 吹 chuī blow
# ENTRY END
#
#
# ENTRY START
# 79 春节 chūn jié Spring Festival; Chinese New
# Year
# ENTRY END
#
#
# ENTRY START
# 80 春天 chūn tiān spring
# ENTRY END
#
#
# ENTRY START
# 81 词 cí word
# ENTRY END
#
#
# ENTRY START
# 82 词典 cídiǎn Dictionary
# ENTRY END
#
#
# ENTRY START
# 83 词语 cíyǔ terms
# ENTRY END
#
#
# ENTRY START
# 84 从小 cóng xiǎo from childhood
# ENTRY END
#
#
# ENTRY START
#
# 5
# ENTRY END
#
#
# ENTRY START
#  86 打工 dǎgōng Work
# ENTRY END
#
#
# ENTRY START
# 87 打算 dǎsuàn Plan
# ENTRY END
#
#
# ENTRY START
# 88 打印 dǎyìn Print
# ENTRY END
#
#
# ENTRY START
# 89 大部分 dà bù fèn most
# ENTRY END
#
#
# ENTRY START
# 90 大大 dà dà greatly; enormously
# ENTRY END
#
#
# ENTRY START
# 91 大多数 dà duō shù most; great majority
# ENTRY END
#
#
# ENTRY START
# 92 大海 dà hǎi sea
# ENTRY END
#
#
# ENTRY START
# 93 大家 dàjiā everybody
# ENTRY END
#
#
# ENTRY START
# 94 大量 dà liàng a lot of; lots of
# ENTRY END
#
#
# ENTRY START
# 95 大门 dà mén door; gate
# ENTRY END
#
#
# ENTRY START
# 96 大人 dà rén adult
# ENTRY END
#
#
# ENTRY START
# 97 大声 dà shēng loud
# ENTRY END
#
#
# ENTRY START
# 98 大小 dà xiǎo size
# ENTRY END
#
#
# ENTRY START
# 99 大衣 dà yī overcoat
# ENTRY END
#
#
# ENTRY START
# 100 大自然 dà zì rán nature
# ENTRY END
#
#
# ENTRY START
# 101 带 dài belt
# ENTRY END
#
#
# ENTRY START
# 102 带来 dài lái bring
# ENTRY END
#
#
# ENTRY START
# 103 单位 dānwèi Company
# ENTRY END
#
#
# ENTRY START
# 104 但 dàn but; however
# ENTRY END
#
#
# ENTRY START
# 105 但是 dàn shì but; however
# ENTRY END
#
#
# ENTRY START
# 106 蛋 dàn egg
# ENTRY END
#
#
# ENTRY START
#
# 6
# ENTRY END
#
#
# ENTRY START
#  108 当时 dāngshí at that time
# ENTRY END
#
#
# ENTRY START
# 109 倒 dǎo fall, topple, fail
# ENTRY END
#
#
# ENTRY START
# 110 到处 dàochù everywhere
# ENTRY END
#
#
# ENTRY START
# 111 倒 dào inverted, reverse
# ENTRY END
#
#
# ENTRY START
# 112 道 dào road; way; path
# ENTRY END
#
#
# ENTRY START
# 113 道理 dàolǐ truth
# ENTRY END
#
#
# ENTRY START
# 114 道路 dào lù road; way; path
# ENTRY END
#
#
# ENTRY START
# 115 得 dé get
# ENTRY END
#
#
# ENTRY START
# 116 得出 dé chū obtain results; reach conclusion
# ENTRY END
#
#
# ENTRY START
# 117 的话 de huà if
# ENTRY END
#
#
# ENTRY START
# 118 得 de auxiliary verb
# ENTRY END
#
#
# ENTRY START
# 119 灯 dēng lamp
# ENTRY END
#
#
# ENTRY START
# 120 等（助、名） děng etc.; and so on
# ENTRY END
#
#
# ENTRY START
# 121 等到 děng dào wait until; by the time
# ENTRY END
#
#
# ENTRY START
# 122 等于 děngyú Be equal to
# ENTRY END
#
#
# ENTRY START
# 123 低 dī low
# ENTRY END
#
#
# ENTRY START
# 124 地球 dìqiú earth
# ENTRY END
#
#
# ENTRY START
# 125 地铁 dìtiě metro
# ENTRY END
#
#
# ENTRY START
# 126 地铁站 dì tiě zhàn subway station
# ENTRY END
#
#
# ENTRY START
# 127 点头 diǎn tóu nod
# ENTRY END
#
#
# ENTRY START
# 128 店 diàn shop; store
# ENTRY END
#
#
# ENTRY START
#
# 7
# ENTRY END
#
#
# ENTRY START
#  130 东北 dōng běi northeast
# ENTRY END
#
#
# ENTRY START
# 131 东方 dōng fāng east
# ENTRY END
#
#
# ENTRY START
# 132 东南 dōng nán southeast
# ENTRY END
#
#
# ENTRY START
# 133 冬天 dōng tiān winter
# ENTRY END
#
#
# ENTRY START
# 134 懂 dǒng understand
# ENTRY END
#
#
# ENTRY START
# 135 懂得 dǒng de know; understand; comprehend
# ENTRY END
#
#
# ENTRY START
# 136 动物 dòngwù Animal
# ENTRY END
#
#
# ENTRY START
# 137 动物园 dòng wù yuán zoo
# ENTRY END
#
#
# ENTRY START
# 138 读音 dú yīn pronunciation
# ENTRY END
#
#
# ENTRY START
# 139 度 dù degree; limit
# ENTRY END
#
#
# ENTRY START
# 140 短 duǎn short
# ENTRY END
#
#
# ENTRY START
# 141 短信 duǎnxìn message
# ENTRY END
#
#
# ENTRY START
# 142 段 duàn paragraph
# ENTRY END
#
#
# ENTRY START
# 143 队 duì team
# ENTRY END
#
#
# ENTRY START
# 144 队长 duì zhǎng team leader; captain
# ENTRY END
#
#
# ENTRY START
# 145 对（介、动） duì to; at; face; be opposite; answer
# ENTRY END
#
#
# ENTRY START
# 146 对话 duìhuà dialogue
# ENTRY END
#
#
# ENTRY START
# 147 对面 duìmiàn Opposite side
# ENTRY END
#
#
# ENTRY START
# 148 多（副） duō much more; far more
# ENTRY END
#
#
# ENTRY START
# 149 多久 duō jiǔ how long
# ENTRY END
#
#
# ENTRY START
# 150 多么 duōme what
# ENTRY END
#
#
# ENTRY START
#
# 8
# ENTRY END
#
#
# ENTRY START
#  152 多云 duō yún cloudy
# ENTRY END
#
#
# ENTRY START
# 153 而且 ér qiě and
# ENTRY END
#
#
# ENTRY START
# 154 发 fā send out
# ENTRY END
#
#
# ENTRY START
# 155 发现 fāxiàn find
# ENTRY END
#
#
# ENTRY START
# 156 饭馆 fàn guǎn restaurant
# ENTRY END
#
#
# ENTRY START
# 157 方便 fāngbiàn convenient
# ENTRY END
#
#
# ENTRY START
# 158 方便面 fāng biàn miàn Instant noodles
# ENTRY END
#
#
# ENTRY START
# 159 方法 fāngfǎ Method
# ENTRY END
#
#
# ENTRY START
# 160 方面 fāngmiàn Aspect
# ENTRY END
#
#
# ENTRY START
# 161 方向 fāngxiàng direction
# ENTRY END
#
#
# ENTRY START
# 162 放下 fàng xià put down; lay down; drop
# ENTRY END
#
#
# ENTRY START
# 163 放心 fàngxīn Don't worry
# ENTRY END
#
#
# ENTRY START
# 164 分（动） fēn divide; part; distribute
# ENTRY END
#
#
# ENTRY START
# 165 分开 fēn kāi separate; part
# ENTRY END
#
#
# ENTRY START
# 166 分数 fēn shù score; mark; fraction
# ENTRY END
#
#
# ENTRY START
# 167 分钟 fēnzhōng Minute
# ENTRY END
#
#
# ENTRY START
# 168 份 fèn share
# ENTRY END
#
#
# ENTRY START
# 169 封（量） fēng (measure word)
# ENTRY END
#
#
# ENTRY START
# 170 服务 fú wù service
# ENTRY END
#
#
# ENTRY START
# 171 复习 fùxí Review
# ENTRY END
#
#
# ENTRY START
# 172 该（动） gāi deserve; should; owe
# ENTRY END
#
#
# ENTRY START
#
# 9
#  over
# ENTRY END
#
#
# ENTRY START
# 174 改变 gǎibiàn change
# ENTRY END
#
#
# ENTRY START
# 175 干杯 gānbēi Cheers!
# ENTRY END
#
#
# ENTRY START
# 176 感到 gǎn dào feel; sense
# ENTRY END
#
#
# ENTRY START
# 177 感动 gǎndòng Be moved
# ENTRY END
#
#
# ENTRY START
# 178 感觉 gǎnjué feel
# ENTRY END
#
#
# ENTRY START
# 179 感谢 gǎnxiè Thank
# ENTRY END
#
#
# ENTRY START
# 180 干活儿 gànhuór work on a job
# ENTRY END
#
#
# ENTRY START
# 181 刚 gāng just
# ENTRY END
#
#
# ENTRY START
# 182 刚才 gāngcái just
# ENTRY END
#
#
# ENTRY START
# 183 刚刚 gāng gāng just; only; just a moment ago
# ENTRY END
#
#
# ENTRY START
# 184 高级 gāojí senior
# ENTRY END
#
#
# ENTRY START
# 185 高中 gāo zhōng senior high school
# ENTRY END
#
#
# ENTRY START
# 186 个子 gèzi Height
# ENTRY END
#
#
# ENTRY START
# 187 更 gèng more
# ENTRY END
#
#
# ENTRY START
# 188 公共汽车 gōnggòngqìchē Bus
# ENTRY END
#
#
# ENTRY START
# 189 公交车 gōng jiāo chē bus
# ENTRY END
#
#
# ENTRY START
# 190 公斤 gōngjīn Kg.
# ENTRY END
#
#
# ENTRY START
# 191 公里 gōnglǐ kilometre
# ENTRY END
#
#
# ENTRY START
# 192 公路 gōng lù highway; highroad
# ENTRY END
#
#
# ENTRY START
# 193 公平 gōngpíng fair
# ENTRY END
#
#
# ENTRY START
#
# 10
# ENTRY END
#
#
# ENTRY START
#  195 公园 gōngyuán Park
# ENTRY END
#
#
# ENTRY START
# 196 狗 gǒu Dog
# ENTRY END
#
#
# ENTRY START
# 197 够 gòu enough
# ENTRY END
#
#
# ENTRY START
# 198 故事 gùshi Story
# ENTRY END
#
#
# ENTRY START
# 199 故意 gùyì deliberately
# ENTRY END
#
#
# ENTRY START
# 200 顾客 gùkè customer
# ENTRY END
#
#
# ENTRY START
# 201 关机 guān jī shutdown
# ENTRY END
#
#
# ENTRY START
# 202 关心 guānxīn Care for
# ENTRY END
#
#
# ENTRY START
# 203 观点 guāndiǎn viewpoint
# ENTRY END
#
#
# ENTRY START
# 204 广场 guǎngchǎng square
# ENTRY END
#
#
# ENTRY START
# 205 广告 guǎnggào Advertisement
# ENTRY END
#
#
# ENTRY START
# 206 国际 guójì international
# ENTRY END
#
#
# ENTRY START
# 207 过来 guò lái come; come over
# ENTRY END
#
#
# ENTRY START
# 208 过年 guò nián celebrate the New Year
# ENTRY END
#
#
# ENTRY START
# 209 过去（动） guò qù go over; pass by
# ENTRY END
#
#
# ENTRY START
# 210 过 guò cross; pass; spend; live
# ENTRY END
#
#
# ENTRY START
# 211 海 hǎi sea
# ENTRY END
#
#
# ENTRY START
# 212 海边 hǎi biān seaside
# ENTRY END
#
#
# ENTRY START
# 213 喊 hǎn shout
# ENTRY END
#
#
# ENTRY START
# 214 好（副） hǎo well; fine; okay
# ENTRY END
#
#
# ENTRY START
# 215 好处 hǎochu benefit
# ENTRY END
#
#
# ENTRY START
#
# 11
# ENTRY END
#
#
# ENTRY START
#  217 好久 hǎo jiǔ for a long time; long
# ENTRY END
#
#
# ENTRY START
# 218 好人 hǎo rén good person
# ENTRY END
#
#
# ENTRY START
# 219 好事 hǎo shì good deed; good thing
# ENTRY END
#
#
# ENTRY START
# 220 好像 hǎoxiàng Be like
# ENTRY END
#
#
# ENTRY START
# 221 合适 héshì appropriate
# ENTRY END
#
#
# ENTRY START
# 222 河 hé river
# ENTRY END
#
#
# ENTRY START
# 223 黑 hēi black
# ENTRY END
#
#
# ENTRY START
# 224 黑板 hēibǎn blackboard
# ENTRY END
#
#
# ENTRY START
# 225 黑色 hēi sè black
# ENTRY END
#
#
# ENTRY START
# 226 红 hóng red
# ENTRY END
#
#
# ENTRY START
# 227 红色 hóng sè red
# ENTRY END
#
#
# ENTRY START
# 228 后来 hòulái later
# ENTRY END
#
#
# ENTRY START
# 229 忽然 hūrán suddenly
# ENTRY END
#
#
# ENTRY START
# 230 湖 hú lake
# ENTRY END
#
#
# ENTRY START
# 231 护照 hùzhào passport
# ENTRY END
#
#
# ENTRY START
# 232 花（动） huā spend; expend
# ENTRY END
#
#
# ENTRY START
# 233 花园 huā yuán garden
# ENTRY END
#
#
# ENTRY START
# 234 画 huà painting
# ENTRY END
#
#
# ENTRY START
# 235 画家 huà jiā painter; artist
# ENTRY END
#
#
# ENTRY START
# 236 画儿 huàr painting; drawing
# ENTRY END
#
#
# ENTRY START
# 237 坏处 huài chù disadvantage; harm
# ENTRY END
#
#
# ENTRY START
#
# 12
# ENTRY END
#
#
# ENTRY START
#  239 欢迎 huānyíng Welcome
# ENTRY END
#
#
# ENTRY START
# 240 换 huàn change
# ENTRY END
#
#
# ENTRY START
# 241 黄 huáng yellow
# ENTRY END
#
#
# ENTRY START
# 242 黄色 huáng sè yellow
# ENTRY END
#
#
# ENTRY START
# 243 回（量） huí (measure word)
# ENTRY END
#
#
# ENTRY START
# 244 回国 huí guó return home from abroad
# ENTRY END
#
#
# ENTRY START
# 245 会（名） huì meeting; gathering; conference;
# union; party
# ENTRY END
#
#
# ENTRY START
# 246 活动 huódòng activity
# ENTRY END
#
#
# ENTRY START
# 247 或 huò or
# ENTRY END
#
#
# ENTRY START
# 248 或者 huòzhě perhaps
# ENTRY END
#
#
# ENTRY START
# 249 机会 jīhuì Opportunity
# ENTRY END
#
#
# ENTRY START
# 250 鸡 jī chicken
# ENTRY END
#
#
# ENTRY START
# 251 级 jí level; rank; grade; degree; step
# ENTRY END
#
#
# ENTRY START
# 252 急 jí fast; anxious; urgent; annoyed
# ENTRY END
#
#
# ENTRY START
# 253 计划 jìhuà plan
# ENTRY END
#
#
# ENTRY START
# 254 计算机 jì suàn jī computer
# ENTRY END
#
#
# ENTRY START
# 255 加 jiā add; increase; put in
# ENTRY END
#
#
# ENTRY START
# 256 加油 jiā yóu oil; refuel; make an all -out
# effort
# ENTRY END
#
#
# ENTRY START
# 257 家（科学家） jiā noun suffix (scientist)
# ENTRY END
#
#
# ENTRY START
#
# 13
# ENTRY END
#
#
# ENTRY START
#  259 家长 jiā zhǎng parent; the head of the family
# ENTRY END
#
#
# ENTRY START
# 260 假 jiǎ false
# ENTRY END
#
#
# ENTRY START
# 261 假期 jià qī holiday; vacation
# ENTRY END
#
#
# ENTRY START
# 262 检查 jiǎnchá inspect; check
# ENTRY END
#
#
# ENTRY START
# 263 见到 jiàn dào see
# ENTRY END
#
#
# ENTRY START
# 264 见过 jiàn guò seen; have seen
# ENTRY END
#
#
# ENTRY START
# 265 件 jiàn piece
# ENTRY END
#
#
# ENTRY START
# 266 健康 jiànkāng Healthy
# ENTRY END
#
#
# ENTRY START
# 267 讲 jiǎng speak
# ENTRY END
#
#
# ENTRY START
# 268 讲话 jiǎng huà speak; talk
# ENTRY END
#
#
# ENTRY START
# 269 交 jiāo hand over
# ENTRY END
#
#
# ENTRY START
# 270 交给 jiāo gěi hand over
# ENTRY END
#
#
# ENTRY START
# 271 交朋友 jiāo péng yǒu make friends
# ENTRY END
#
#
# ENTRY START
# 272 交通 jiāotōng traffic
# ENTRY END
#
#
# ENTRY START
# 273 角 jiǎo horn
# ENTRY END
#
#
# ENTRY START
# 274 角度 jiǎodù angle
# ENTRY END
#
#
# ENTRY START
# 275 饺子 jiǎozi Dumplings
# ENTRY END
#
#
# ENTRY START
# 276 脚 jiǎo foot
# ENTRY END
#
#
# ENTRY START
# 277 叫作 jiào zuò be called; be known as
# ENTRY END
#
#
# ENTRY START
# 278 教师 jiào shī teacher
# ENTRY END
#
#
# ENTRY START
# 279 教室 jiàoshì Classroom
# ENTRY END
#
#
# ENTRY START
#
# 14
# ENTRY END
#
#
# ENTRY START
#  281 教育 jiàoyù education
# ENTRY END
#
#
# ENTRY START
# 282 接 jiē meet， pick
# ENTRY END
#
#
# ENTRY START
# 283 接到 jiē dào receive
# ENTRY END
#
#
# ENTRY START
# 284 接受 jiēshòu accept
# ENTRY END
#
#
# ENTRY START
# 285 接下来 jiē xià lái next
# ENTRY END
#
#
# ENTRY START
# 286 接着 jiēzhe Next
# ENTRY END
#
#
# ENTRY START
# 287 街 jiē street
# ENTRY END
#
#
# ENTRY START
# 288 节（名、量） jié festival; holiday; joint; (measure
# word)
# ENTRY END
#
#
# ENTRY START
# 289 节目 jiémù program
# ENTRY END
#
#
# ENTRY START
# 290 节日 jiérì festival
# ENTRY END
#
#
# ENTRY START
# 291 结果 jiéguǒ Result
# ENTRY END
#
#
# ENTRY START
# 292 借 jiè borrow
# ENTRY END
#
#
# ENTRY START
# 293 斤 jīn a unit of weight (=1/2 kilogram)
# ENTRY END
#
#
# ENTRY START
# 294 今后 jīn hòu from now on; in the future
# ENTRY END
#
#
# ENTRY START
# 295 进入 jìn rù enter; go in; join
# ENTRY END
#
#
# ENTRY START
# 296 进行 jìnxíng Conduct
# ENTRY END
#
#
# ENTRY START
# 297 近 jìn near
# ENTRY END
#
#
# ENTRY START
# 298 经常 jīngcháng Often
# ENTRY END
#
#
# ENTRY START
# 299 经过 jīngguò after, through
# ENTRY END
#
#
# ENTRY START
# 300 经理 jīnglǐ manager
# ENTRY END
#
#
# ENTRY START
#
# 15
# ENTRY END
#
#
# ENTRY START
#  302 酒店 jiǔ diàn hotel
# ENTRY END
#
#
# ENTRY START
# 303 就要 jiù yào be going to; be about to
# ENTRY END
#
#
# ENTRY START
# 304 举 jǔ lift
# ENTRY END
#
#
# ENTRY START
# 305 举手 jǔ shǒu raise one's hand or hands
# ENTRY END
#
#
# ENTRY START
# 306 举行 jǔxíng hold
# ENTRY END
#
#
# ENTRY START
# 307 句 jù sentence
# ENTRY END
#
#
# ENTRY START
# 308 句子 jùzi sentence
# ENTRY END
#
#
# ENTRY START
# 309 卡 kǎ card
# ENTRY END
#
#
# ENTRY START
# 310 开机 kāi jī starting up
# ENTRY END
#
#
# ENTRY START
# 311 开心 kāixīn Happy
# ENTRY END
#
#
# ENTRY START
# 312 开学 kāi xué school opens; term begins
# ENTRY END
#
#
# ENTRY START
# 313 看法 kànfǎ view
# ENTRY END
#
#
# ENTRY START
# 314 考生 kǎo shēng examinee
# ENTRY END
#
#
# ENTRY START
# 315 靠 kào lean
# ENTRY END
#
#
# ENTRY START
# 316 科 kē subject; family; section
# ENTRY END
#
#
# ENTRY START
# 317 科学 kēxué science
# ENTRY END
#
#
# ENTRY START
# 318 可爱 kě'ài Lovely
# ENTRY END
#
#
# ENTRY START
# 319 可能 kěnéng Probably
# ENTRY END
#
#
# ENTRY START
# 320 可怕 kěpà dreadful
# ENTRY END
#
#
# ENTRY START
# 321 可是 kěshì however
# ENTRY END
#
#
# ENTRY START
# 322 可以 kěyǐ Sure
# ENTRY END
#
#
# ENTRY START
#
# 16
# ENTRY END
#
#
# ENTRY START
#  324 刻（量） kè a quarter (of an hour)
# ENTRY END
#
#
# ENTRY START
# 325 客人 kèrén Guest
# ENTRY END
#
#
# ENTRY START
# 326 课堂 kè táng classroom
# ENTRY END
#
#
# ENTRY START
# 327 空气 kōngqì atmosphere
# ENTRY END
#
#
# ENTRY START
# 328 哭 kū cry
# ENTRY END
#
#
# ENTRY START
# 329 快餐 kuài cān fast food
# ENTRY END
#
#
# ENTRY START
# 330 快点儿 kuài diǎnr hurry up
# ENTRY END
#
#
# ENTRY START
# 331 快乐 kuàilè happy
# ENTRY END
#
#
# ENTRY START
# 332 快要 kuài yào be about to; be going to
# ENTRY END
#
#
# ENTRY START
# 333 筷子 kuàizi chopsticks
# ENTRY END
#
#
# ENTRY START
# 334 拉 lā pull
# ENTRY END
#
#
# ENTRY START
# 335 来自 láizì Come from
# ENTRY END
#
#
# ENTRY START
# 336 蓝 lán blue
# ENTRY END
#
#
# ENTRY START
# 337 蓝色 lán sè blue
# ENTRY END
#
#
# ENTRY START
# 338 篮球 lán qiú basketball
# ENTRY END
#
#
# ENTRY START
# 339 老（副） lǎo always; constantly
# ENTRY END
#
#
# ENTRY START
# 340 老（老王） lǎo
# （ lǎo wáng ） noun prefix (Lao Wang)
# ENTRY END
#
#
# ENTRY START
# 341 老年 lǎo nián elderly
# ENTRY END
#
#
# ENTRY START
# 342 老朋友 lǎo péng yǒu old friend
# ENTRY END
#
#
# ENTRY START
# 343 老是 lǎo shì always; all times
# ENTRY END
#
#
# ENTRY START
#
# 17
# ENTRY END
#
#
# ENTRY START
#  345 离开 líkāi leave
# ENTRY END
#
#
# ENTRY START
# 346 礼物 lǐwù gift
# ENTRY END
#
#
# ENTRY START
# 347 里头 lǐ tou inside
# ENTRY END
#
#
# ENTRY START
# 348 理想 lǐxiǎng ideal
# ENTRY END
#
#
# ENTRY START
# 349 例如 lìrú for example
# ENTRY END
#
#
# ENTRY START
# 350 例子 lì zi example
# ENTRY END
#
#
# ENTRY START
# 351 脸 liǎn face
# ENTRY END
#
#
# ENTRY START
# 352 练 liàn practice; train
# ENTRY END
#
#
# ENTRY START
# 353 练习 liànxí Practice
# ENTRY END
#
#
# ENTRY START
# 354 凉 liáng cool
# ENTRY END
#
#
# ENTRY START
# 355 凉快 liángkuai Pleasantly cool
# ENTRY END
#
#
# ENTRY START
# 356 两（量） liǎng a unit of weight (=50 grams)
# ENTRY END
#
#
# ENTRY START
# 357 亮 liàng bright
# ENTRY END
#
#
# ENTRY START
# 358 辆 liàng Car (measure word)
# ENTRY END
#
#
# ENTRY START
# 359 零下 líng xià below zero
# ENTRY END
#
#
# ENTRY START
# 360 留 liú stay
# ENTRY END
#
#
# ENTRY START
# 361 留下 liú xià stay; remain
# ENTRY END
#
#
# ENTRY START
# 362 留学生 liú xué shēng student studying abroad;
# returned student
# ENTRY END
#
#
# ENTRY START
# 363 流 liú flow; spread
# ENTRY END
#
#
# ENTRY START
# 364 流利 liúlì fluent
# ENTRY END
#
#
# ENTRY START
#
# 18
# ENTRY END
#
#
# ENTRY START
#  366 路边 lù biān roadside; wayside
# ENTRY END
#
#
# ENTRY START
# 367 旅客 lǚ kè passenger; traveler
# ENTRY END
#
#
# ENTRY START
# 368 旅行 lǚxíng travel
# ENTRY END
#
#
# ENTRY START
# 369 旅游 lǚyóu Tourism
# ENTRY END
#
#
# ENTRY START
# 370 绿 lǜ green
# ENTRY END
#
#
# ENTRY START
# 371 绿色 lǜ sè green
# ENTRY END
#
#
# ENTRY START
# 372 卖 mài sell
# ENTRY END
#
#
# ENTRY START
# 373 满 mǎn full
# ENTRY END
#
#
# ENTRY START
# 374 满意 mǎnyì Satisfied
# ENTRY END
#
#
# ENTRY START
# 375 猫 māo cat
# ENTRY END
#
#
# ENTRY START
# 376 米（量） mǐ meter
# ENTRY END
#
#
# ENTRY START
# 377 面¹（名、量） miàn ¹ (measure word); side; aspect
# ENTRY END
#
#
# ENTRY START
# 378 面²（名） miàn ² face; surface; outside; side;
# scale; flour
# ENTRY END
#
#
# ENTRY START
# 379 面前 miàn qián in front of; before
# ENTRY END
#
#
# ENTRY START
# 380 名 míng name
# ENTRY END
#
#
# ENTRY START
# 381 名称 míng chēng name; designation
# ENTRY END
#
#
# ENTRY START
# 382 名单 míng dān list
# ENTRY END
#
#
# ENTRY START
# 383 明星 míngxīng Star
# ENTRY END
#
#
# ENTRY START
# 384 目的 mùdì objective
# ENTRY END
#
#
# ENTRY START
# 385 拿出 ná chū take out
# ENTRY END
#
#
# ENTRY START
#
# 19
# ENTRY END
#
#
# ENTRY START
#  387 那（连） nà then; in that case
# ENTRY END
#
#
# ENTRY START
# 388 那会儿 nà huìr at that time; then
# ENTRY END
#
#
# ENTRY START
# 389 那么 nà me like that; in that way
# ENTRY END
#
#
# ENTRY START
# 390 那时候｜那时 nà shí
# hou ｜ nà shí at that time
# ENTRY END
#
#
# ENTRY START
# 391 那样 nà yàng that kind; like that; such
# ENTRY END
#
#
# ENTRY START
# 392 南方 nán fāng south
# ENTRY END
#
#
# ENTRY START
# 393 难过 nánguò Sorry
# ENTRY END
#
#
# ENTRY START
# 394 难看 nán kàn ugly
# ENTRY END
#
#
# ENTRY START
# 395 难受 nánshòu Uncomfortable
# ENTRY END
#
#
# ENTRY START
# 396 难题 nán tí problem; difficult problem;
# puzzle
# ENTRY END
#
#
# ENTRY START
# 397 难听 nán tīng unpleasant to hear
# ENTRY END
#
#
# ENTRY START
# 398 能够 néng gòu be able to; can
# ENTRY END
#
#
# ENTRY START
# 399 年级 niánjí grade
# ENTRY END
#
#
# ENTRY START
# 400 年轻 niánqīng Young
# ENTRY END
#
#
# ENTRY START
# 401 鸟 niǎo bird
# ENTRY END
#
#
# ENTRY START
# 402 弄 nòng get, make
# ENTRY END
#
#
# ENTRY START
# 403 努力 nǔlì Strive
# ENTRY END
#
#
# ENTRY START
# 404 爬 pá climb; creep; scramble
# ENTRY END
#
#
# ENTRY START
# 405 爬山 páshān Mountain climbing
# ENTRY END
#
#
# ENTRY START
#
# 20
# ENTRY END
#
#
# ENTRY START
#  407 排（名、量） pái row; line
# ENTRY END
#
#
# ENTRY START
# 408 排队 páiduì queue; stand in a line
# ENTRY END
#
#
# ENTRY START
# 409 排球 pái qiú volleyball
# ENTRY END
#
#
# ENTRY START
# 410 碰 pèng touch, meet
# ENTRY END
#
#
# ENTRY START
# 411 碰到 pèng dào meet; run into; bump into
# ENTRY END
#
#
# ENTRY START
# 412 碰见 pèng jiàn meet; run into; bump into
# ENTRY END
#
#
# ENTRY START
# 413 篇 piān piece
# ENTRY END
#
#
# ENTRY START
# 414 便宜 piányi Cheap
# ENTRY END
#
#
# ENTRY START
# 415 片 piàn slice
# ENTRY END
#
#
# ENTRY START
# 416 漂亮 piàoliang Well done!； beautiful
# ENTRY END
#
#
# ENTRY START
# 417 平 píng flat
# ENTRY END
#
#
# ENTRY START
# 418 平安 píng'ān sound and safe
# ENTRY END
#
#
# ENTRY START
# 419 平常 píngcháng Usual
# ENTRY END
#
#
# ENTRY START
# 420 平等 píngděng equality
# ENTRY END
#
#
# ENTRY START
# 421 平时 píngshí peacetime
# ENTRY END
#
#
# ENTRY START
# 422 瓶 píng bottle
# ENTRY END
#
#
# ENTRY START
# 423 瓶子 píngzi Bottle
# ENTRY END
#
#
# ENTRY START
# 424 普通 pǔ tōng ordinary; general; average;
# common
# ENTRY END
#
#
# ENTRY START
# 425 普通话 pǔtōnghuà Mandarin
# ENTRY END
#
#
# ENTRY START
# 426 其他 qítā Other
# ENTRY END
#
#
# ENTRY START
#
# 21
# ENTRY END
#
#
# ENTRY START
#  428 骑 qí ride
# ENTRY END
#
#
# ENTRY START
# 429 骑车 qí chē cycle
# ENTRY END
#
#
# ENTRY START
# 430 起飞 qǐfēi take off
# ENTRY END
#
#
# ENTRY START
# 431 气 qì air; gas; breath
# ENTRY END
#
#
# ENTRY START
# 432 气温 qì wēn air temperature
# ENTRY END
#
#
# ENTRY START
# 433 千 qiān thousand
# ENTRY END
#
#
# ENTRY START
# 434 千克 qiān kè kilogram
# ENTRY END
#
#
# ENTRY START
# 435 前年 qián nián the year before last
# ENTRY END
#
#
# ENTRY START
# 436 墙 qiáng wall
# ENTRY END
#
#
# ENTRY START
# 437 青年 qīng nián youth; young
# ENTRY END
#
#
# ENTRY START
# 438 青少年 qīngshàonián Teenagers
# ENTRY END
#
#
# ENTRY START
# 439 轻 qīng light
# ENTRY END
#
#
# ENTRY START
# 440 清楚 qīngchu clear
# ENTRY END
#
#
# ENTRY START
# 441 晴 qíng Sunny
# ENTRY END
#
#
# ENTRY START
# 442 晴天 qíng tiān sunny day
# ENTRY END
#
#
# ENTRY START
# 443 请客 qǐng kè stand treat; entertain
# ENTRY END
#
#
# ENTRY START
# 444 请求 qǐngqiú request
# ENTRY END
#
#
# ENTRY START
# 445 秋天 qiū tiān fall; autumn
# ENTRY END
#
#
# ENTRY START
# 446 求 qiú request; beg; entreat; beseech
# ENTRY END
#
#
# ENTRY START
# 447 球场 qiú chǎng court; field
# ENTRY END
#
#
# ENTRY START
# 448 球队 qiú duì team
# ENTRY END
#
#
# ENTRY START
#
# 22
# ENTRY END
#
#
# ENTRY START
#  450 取 qǔ take
# ENTRY END
#
#
# ENTRY START
# 451 取得 qǔ dé acquire; gain; obtain
# ENTRY END
#
#
# ENTRY START
# 452 全 quán whole; entire; complete
# ENTRY END
#
#
# ENTRY START
# 453 全部 quánbù whole
# ENTRY END
#
#
# ENTRY START
# 454 全国 quán guó nationwide; entire country
# ENTRY END
#
#
# ENTRY START
# 455 全家 quán jiā whole family
# ENTRY END
#
#
# ENTRY START
# 456 全年 quán nián annual; yearly
# ENTRY END
#
#
# ENTRY START
# 457 全身 quán shēn whole body
# ENTRY END
#
#
# ENTRY START
# 458 全体 quán tǐ all; entire; whole
# ENTRY END
#
#
# ENTRY START
# 459 然后 ránhòu Then
# ENTRY END
#
#
# ENTRY START
# 460 让 ràng Give Way
# ENTRY END
#
#
# ENTRY START
# 461 热情 rèqíng Enthusiasm
# ENTRY END
#
#
# ENTRY START
# 462 人口 rénkǒu population
# ENTRY END
#
#
# ENTRY START
# 463 人们 rén men people
# ENTRY END
#
#
# ENTRY START
# 464 人数 rén shù number of people
# ENTRY END
#
#
# ENTRY START
# 465 认为 rènwéi think
# ENTRY END
#
#
# ENTRY START
# 466 日报 rì bào daily, journal
# ENTRY END
#
#
# ENTRY START
# 467 日子 rìzi life, days
# ENTRY END
#
#
# ENTRY START
# 468 如果 rúguǒ If
# ENTRY END
#
#
# ENTRY START
# 469 入口 rùkǒu Entrance
# ENTRY END
#
#
# ENTRY START
# 470 商量 shāngliang discuss
# ENTRY END
#
#
# ENTRY START
#
# 23
# ENTRY END
#
#
# ENTRY START
#  472 上周 shàng zhōu last week
# ENTRY END
#
#
# ENTRY START
# 473 少数 shǎo shù small number; few; minority
# ENTRY END
#
#
# ENTRY START
# 474 少年 shào nián juvenile; young person
# ENTRY END
#
#
# ENTRY START
# 475 身边 shēn biān at [by] one's side
# ENTRY END
#
#
# ENTRY START
# 476 什么样 shén me yàng what kind
# ENTRY END
#
#
# ENTRY START
# 477 生（动） shēng give birth; be born
# ENTRY END
#
#
# ENTRY START
# 478 生词 shēng cí new word
# ENTRY END
#
#
# ENTRY START
# 479 生活 shēnghuó Life
# ENTRY END
#
#
# ENTRY START
# 480 声音 shēngyīn voice
# ENTRY END
#
#
# ENTRY START
# 481 省（名） shěng province
# ENTRY END
#
#
# ENTRY START
# 482 省（动） shěng economize; save; omit; leave
# out
# ENTRY END
#
#
# ENTRY START
# 483 十分 shífēn very
# ENTRY END
#
#
# ENTRY START
# 484 实际 shíjì Actual
# ENTRY END
#
#
# ENTRY START
# 485 实习 shíxí Internship
# ENTRY END
#
#
# ENTRY START
# 486 实现 shíxiàn Realization
# ENTRY END
#
#
# ENTRY START
# 487 实在 shízài real; indeeed
# ENTRY END
#
#
# ENTRY START
# 488 实在 shízai done carefully
# ENTRY END
#
#
# ENTRY START
# 489 食物 shíwù food
# ENTRY END
#
#
# ENTRY START
# 490 使用 shǐyòng Use
# ENTRY END
#
#
# ENTRY START
# 491 市 shì city
# ENTRY END
#
#
# ENTRY START
#
# 24
# ENTRY END
#
#
# ENTRY START
#  493 事情 shìqing Thing
# ENTRY END
#
#
# ENTRY START
# 494 收 shōu collect
# ENTRY END
#
#
# ENTRY START
# 495 收到 shōu dào receive; obtain
# ENTRY END
#
#
# ENTRY START
# 496 收入 shōurù income
# ENTRY END
#
#
# ENTRY START
# ...
# ENTRY END
#
#
# ENTRY START
# 871 吸毒 xī dú drug; drug addict
# ENTRY END
#
#
# ENTRY START
# 872 牺牲 xīshēng sacrifice
# ENTRY END
#
#
# ENTRY START
#
# 53
# ENTRY END
#
#
# ENTRY START
#  874 戏曲 xì qǔ drama; Chinese opera
# ENTRY END
#
#
# ENTRY START
# 875 细胞 xìbāo Cells
# ENTRY END
#
#
# ENTRY START
# 876 细菌 xìjūn Bacteria
# ENTRY END
#
#
# ENTRY START
# 877 先锋 xiān fēng pioneer; vanguard
# ENTRY END
#
#
# ENTRY START
# 878 嫌 xián dislike and avoid
# ENTRY END
#
#
# ENTRY START
# 879 显出 xiǎn chū show; manifest
# ENTRY END
#
#
# ENTRY START
# 880 险 xiǎn danger; risk; danger;
# dangerous; sinister; nearly
# ENTRY END
#
#
# ENTRY START
# 881 线路 xiàn lù line; route; circuit
# ENTRY END
#
#
# ENTRY START
# 882 陷入 xiànrù fall into
# ENTRY END
#
#
# ENTRY START
# 883 响声 xiǎng shēng sound; noise
# ENTRY END
#
#
# ENTRY START
# 884 想不到 xiǎng bú dào unexpected
# ENTRY END
#
#
# ENTRY START
# 885 消耗 xiāohào consume
# ENTRY END
#
#
# ENTRY START
# 886 消灭 xiāomiè eliminate
# ENTRY END
#
#
# ENTRY START
# 887 小费 xiǎo fèi tip
# ENTRY END
#
#
# ENTRY START
# 888 小麦 xiǎomài Wheat
# ENTRY END
#
#
# ENTRY START
# 889 小于 xiǎo yú less than
# ENTRY END
#
#
# ENTRY START
# 890 晓得 xiǎo dé know
# ENTRY END
#
#
# ENTRY START
# 891 笑脸 xiào liǎn smiley; smiling face
# ENTRY END
#
#
# ENTRY START
# 892 笑容 xiào róng smiling expression; smile
# ENTRY END
#
#
# ENTRY START
# 893 笑声 xiào shēng laughter; laughing
# ENTRY END
#
#
# ENTRY START
#
# 54
# ENTRY END
#
#
# ENTRY START
#  895 协商 xiéshāng consult
# ENTRY END
#
#
# ENTRY START
# 896 协调 xiétiáo coordinate
# ENTRY END
#
#
# ENTRY START
# 897 协助 xiézhù assist
# ENTRY END
#
#
# ENTRY START
# 898 写字楼 xiě zì lóu office building
# ENTRY END
#
#
# ENTRY START
# 899 写字台 xiě zì tái writing desk; desk
# ENTRY END
#
#
# ENTRY START
# 900 心灵 xīnlíng Heart
# ENTRY END
#
#
# ENTRY START
# 901 心愿 xīn yuàn wish; aspiration
# ENTRY END
#
#
# ENTRY START
# 902 心脏 xīnzàng heart
# ENTRY END
#
#
# ENTRY START
# 903 心脏病 xīn zàng bìng heart disease
# ENTRY END
#
#
# ENTRY START
# 904 新人 xīn rén newcomer; new personality;
# new talent
# ENTRY END
#
#
# ENTRY START
# 905 新兴 xīn xīng new; emerging; newly -
# developing
# ENTRY END
#
#
# ENTRY START
# 906 薪水 xīnshui salary
# ENTRY END
#
#
# ENTRY START
# 907 信仰 xìnyǎng Faith
# ENTRY END
#
#
# ENTRY START
# 908 信用 xìn yòng credit
# ENTRY END
#
#
# ENTRY START
# 909 兴旺 xīngwàng Prosperous
# ENTRY END
#
#
# ENTRY START
# 910 行程 xíng chéng travel; itinerary
# ENTRY END
#
#
# ENTRY START
# 911 形 xíng form; shape; body; entity;
# appear; look
# ENTRY END
#
#
# ENTRY START
#
# 55
# ENTRY END
#
#
# ENTRY START
#  913 凶手 xiōngshǒu Murderer
# ENTRY END
#
#
# ENTRY START
# 914 修车 xiū chē car repair; car repairing
# ENTRY END
#
#
# ENTRY START
# 915 袖珍 xiù zhēn pocket -size; pocket
# ENTRY END
#
#
# ENTRY START
# 916 悬 xuán hang; suspend; feel anxious;
# outstanding; dangerous
# ENTRY END
#
#
# ENTRY START
# 917 旋转 xuánzhuǎn rotate
# ENTRY END
#
#
# ENTRY START
# 918 选拔 xuǎnbá Selection
# ENTRY END
#
#
# ENTRY START
# 919 选举 xuǎnjǔ Election
# ENTRY END
#
#
# ENTRY START
# 920 学会 xué huì learn; master; study
# ENTRY END
#
#
# ENTRY START
# 921 学员 xué yuán student; trainee
# ENTRY END
#
#
# ENTRY START
# 922 血管 xuè guǎn blood vessel; artery; vein
# ENTRY END
#
#
# ENTRY START
# 923 血液 xuè yè blood
# ENTRY END
#
#
# ENTRY START
# 924 循环 xúnhuán loop
# ENTRY END
#
#
# ENTRY START
# 925 压迫 yāpò Oppression
# ENTRY END
#
#
# ENTRY START
# 926 烟花 yān huā fireworks
# ENTRY END
#
#
# ENTRY START
# 927 沿 yán along; follow
# ENTRY END
#
#
# ENTRY START
# 928 沿海 yánhǎi coastal
# ENTRY END
#
#
# ENTRY START
# 929 沿着 yán zhe along
# ENTRY END
#
#
# ENTRY START
# 930 研发 yán fā research and development
# ENTRY END
#
#
# ENTRY START
# 931 眼看 yǎn kàn see; soon; in a moment;
# watch helplessly
# ENTRY END
#
#
# ENTRY START
#
# 56
# ENTRY END
#
#
# ENTRY START
#  933 宴会 yànhuì banquet
# ENTRY END
#
#
# ENTRY START
# 934 洋 yáng ocean; vast; multitudinous;
# foreign
# ENTRY END
#
#
# ENTRY START
# 935 仰 yǎng look up; face upward
# ENTRY END
#
#
# ENTRY START
# 936 养老 yǎng lǎo pension; provide for the
# aged
# ENTRY END
#
#
# ENTRY START
# 937 氧气 yǎngqì oxygen
# ENTRY END
#
#
# ENTRY START
# 938 样 yàng appearance; shape; sample;
# model; pattern; kind; type
# ENTRY END
#
#
# ENTRY START
# 939 药品 yào pǐn drug; medicine; medicament
# ENTRY END
#
#
# ENTRY START
# 940 要不然 yào bù rán otherwise
# ENTRY END
#
#
# ENTRY START
# 941 要好 yào hǎo be close friends; try hard to
# make progress; better
# ENTRY END
#
#
# ENTRY START
# 942 要么 yào me or; either ... or ...
# ENTRY END
#
#
# ENTRY START
# 943 要素 yàosù Essential factor
# ENTRY END
#
#
# ENTRY START
# 944 野 yě open space; field; wild;
# uncultivated; rude; rough;
# out of office
# ENTRY END
#
#
# ENTRY START
# 945 野生 yě shēng wild; uncultivated; feral
# ENTRY END
#
#
# ENTRY START
# 946 医药 yī yào medicine; curative
# ENTRY END
#
#
# ENTRY START
# 947 依次 yī cì in proper order; successively
# ENTRY END
#
#
# ENTRY START
#
# 57
# ENTRY END
#
#
# ENTRY START
#  949 一次性 yí cì xìng disposable; single use
# ENTRY END
#
#
# ENTRY START
# 950 一代 yí dài generation
# ENTRY END
#
#
# ENTRY START
# 951 一道 yí dào together; a streak of
# ENTRY END
#
#
# ENTRY START
# 952 一贯 yíguàn consistent
# ENTRY END
#
#
# ENTRY START
# 953 一路上 yí lù shàng all the way; along the way
# ENTRY END
#
#
# ENTRY START
# 954 仪器 yíqì instrument
# ENTRY END
#
#
# ENTRY START
# 955 仪式 yíshì Ceremony
# ENTRY END
#
#
# ENTRY START
# 956 遗憾 yíhàn regret; pity
# ENTRY END
#
#
# ENTRY START
# 957 一番 yì fān some; one time
# ENTRY END
#
#
# ENTRY START
# 958 一模一样 yì mú yí yàng exactly the same; as like as
# two peas
# ENTRY END
#
#
# ENTRY START
# 959 一齐 yì qí all together; simultaneously;
# in unison
# ENTRY END
#
#
# ENTRY START
# 960 一时 yì shí for a short while; temporary;
# momentary
# ENTRY END
#
#
# ENTRY START
# 961 一同 yì tóng together; at the same time
# and place
# ENTRY END
#
#
# ENTRY START
# 962 一行 yì xíng delegation; a group
# travelling together; party
# ENTRY END
#
#
# ENTRY START
# 963 艺人 yì rén actor; artist; artisan;
# handicraftsman
# ENTRY END
#
#
# ENTRY START
#
# 58
#  issue under discussion
# ENTRY END
#
#
# ENTRY START
# 965 异常 yìcháng abnormal
# ENTRY END
#
#
# ENTRY START
# 966 意想不到 yì xiǎng bù dào unexpected; surprising; out
# of the blue; unpredicted
# ENTRY END
#
#
# ENTRY START
# 967 意愿 yì yuàn wish; desire; aspiration;
# volitional
# ENTRY END
#
#
# ENTRY START
# 968 因 yīn cause; reason; because
# ENTRY END
#
#
# ENTRY START
# 969 因素 yīnsù Factor
# ENTRY END
#
#
# ENTRY START
# 970 阴谋 yīnmóu conspiracy
# ENTRY END
#
#
# ENTRY START
# 971 阴影 yīn yǐng shadow; shade
# ENTRY END
#
#
# ENTRY START
# 972 音量 yīn liàng volume; sound volume
# ENTRY END
#
#
# ENTRY START
# 973 音像 yīn xiàng audiovisual; audio -video
# ENTRY END
#
#
# ENTRY START
# 974 隐藏 yǐn cáng hide; hiding; conceal; put
# out of sight
# ENTRY END
#
#
# ENTRY START
# 975 隐私 yǐnsī Privacy
# ENTRY END
#
#
# ENTRY START
# 976 印 yìn seal; stamp; mark; print;
# impress
# ENTRY END
#
#
# ENTRY START
# 977 英雄 yīngxióng Hero
# ENTRY END
#
#
# ENTRY START
# 978 迎来 yíng lái usher in; greet
# ENTRY END
#
#
# ENTRY START
# 979 影迷 yǐng mí movie fan; film fan
# ENTRY END
#
#
# ENTRY START
# 980 影星 yǐng xīng movie star
# ENTRY END
#
#
# ENTRY START
#
# 59
# ENTRY END
#
#
# ENTRY START
#  982 应急 yìng jí meet an urgent need; meet
# an emergency; meet a
# contingency
# ENTRY END
#
#
# ENTRY START
# 983 用处 yòng chù use; good; usefulness
# ENTRY END
#
#
# ENTRY START
# 984 用得着 yòng de zháo useful; need
# ENTRY END
#
#
# ENTRY START
# 985 用法 yòng fǎ usage; use
# ENTRY END
#
#
# ENTRY START
# 986 用品 yòng pǐn supplies; appliance
# ENTRY END
#
#
# ENTRY START
# 987 用心 yòng xīn attentively; intention;
# diligently
# ENTRY END
#
#
# ENTRY START
# 988 优质 yōu zhì high quality; high grade
# ENTRY END
#
#
# ENTRY START
# 989 游人 yóu rén visitor; tourist; sightseer
# ENTRY END
#
#
# ENTRY START
# 990 游玩 yóu wán amuse; play; stroll; playing
# ENTRY END
#
#
# ENTRY START
# 991 游戏机 yóu xì jī game console; game
# machine
# ENTRY END
#
#
# ENTRY START
# 992 游行 yóu xíng parade; march;
# demonstration; procession
# ENTRY END
#
#
# ENTRY START
# 993 有关 yǒu guān related; concerning; relate;
# concern
# ENTRY END
#
#
# ENTRY START
# 994 有没有 yǒu méi yǒu do you have...?; Have you
# ever...? ; Is there any...?
# ENTRY END
#
#
# ENTRY START
#
# 60
# ENTRY END
#
#
# ENTRY START
#  996 于 yú (preposition)
# ENTRY END
#
#
# ENTRY START
# 997 娱乐 yúlè entertainment
# ENTRY END
#
#
# ENTRY START
# 998 愉快 yúkuài Cheerful
# ENTRY END
#
#
# ENTRY START
# 999 与 yǔ and
# ENTRY END
#
#
# ENTRY START
# 1000 宇航员 yǔ háng yuán cosmonaut; astronaut
# ENTRY END
#
#
# ENTRY START
# 1001 雨衣 yǔ yī raincoat
# ENTRY END
#
#
# ENTRY START
# 1002 预约 yù yuē reservation; reserve; make
# an appointment
# ENTRY END
#
#
# ENTRY START
# 1003 元素 yuánsù element
# ENTRY END
#
#
# ENTRY START
# 1004 园 yuán garden; an area of land for
# growing plants; a place for
# public recreation
# ENTRY END
#
#
# ENTRY START
# 1005 园地 yuán dì garden; field
# ENTRY END
#
#
# ENTRY START
# 1006 原 yuán primary; original; former;
# raw; pardon; level
# ENTRY END
#
#
# ENTRY START
# 1007 原告 yuángào accuser
# ENTRY END
#
#
# ENTRY START
# 1008 原谅 yuánliàng Forgive
# ENTRY END
#
#
# ENTRY START
# 1009 圆珠笔 yuán zhū bǐ ball point pen
# ENTRY END
#
#
# ENTRY START
# 1010 援助 yuán zhù help; support; aid; back up
# ENTRY END
#
#
# ENTRY START
# 1011 缘故 yuángù Reason
# ENTRY END
#
#
# ENTRY START
# 1012 远方 yuǎn fāng distance
# ENTRY END
#
#
# ENTRY START
#
# 61
# ENTRY END
#
#
# ENTRY START
#  1014 远远 yuǎn yuǎn far away
# ENTRY END
#
#
# ENTRY START
# 1015 约定 yuē dìng appoint; arrange; promise;
# agreement
# ENTRY END
#
#
# ENTRY START
# 1016 乐曲 yuè qǔ music; musical composition
# ENTRY END
#
#
# ENTRY START
# 1017 晕 yūn faint
# ENTRY END
#
#
# ENTRY START
# 1018 允许 yǔnxǔ allow
# ENTRY END
#
#
# ENTRY START
# 1019 运作 yùn zuò operation; operate
# ENTRY END
#
#
# ENTRY START
# 1020 晕车 yùn chē carsickness; motion sickness
# ENTRY END
#
#
# ENTRY START
# 1021 杂 zá miscellaneous; varied; mixed;
# mix
# ENTRY END
#
#
# ENTRY START
# 1022 再生 zài shēng regeneration; regenerate;
# revive
# ENTRY END
#
#
# ENTRY START
# 1023 再说 zài shuō besides; put off until some
# time later; say
# ENTRY END
#
#
# ENTRY START
# 1024 遭到 zāo dào suffer; suffered; meet with
# ENTRY END
#
#
# ENTRY START
# 1025 遭受 zāoshòu Suffer
# ENTRY END
#
#
# ENTRY START
# 1026 遭遇 zāoyù encounter
# ENTRY END
#
#
# ENTRY START
# 1027 早晚 zǎo wǎn sooner or later; morning and
# evening; time; some day
# ENTRY END
#
#
# ENTRY START
# 1028 增进 zēng jìn enhance; promote
# ENTRY END
#
#
# ENTRY START
#
# 62
# ENTRY END
#
#
# ENTRY START
#  1030 扎 zhā Tie
# ENTRY END
#
#
# ENTRY START
# 1031 扎实 zhāshi solid
# ENTRY END
#
#
# ENTRY START
# 1032 炸 zhà explode; burst; bomb; flare
# up
# ENTRY END
#
#
# ENTRY START
# 1033 炸弹 zhà dàn bomb
# ENTRY END
#
#
# ENTRY START
# 1034 炸药 zhà yào explosive; dynamite
# ENTRY END
#
#
# ENTRY START
# 1035 债 zhài debt; loan; owing
# ENTRY END
#
#
# ENTRY START
# 1036 占据 zhànjù Occupy
# ENTRY END
#
#
# ENTRY START
# 1037 战场 zhàn chǎng battleground; battlefield
# ENTRY END
#
#
# ENTRY START
# 1038 战略 zhànlüè strategy
# ENTRY END
#
#
# ENTRY START
# 1039 战术 zhànshù tactics
# ENTRY END
#
#
# ENTRY START
# 1040 战友 zhàn yǒu comrades in arms
# ENTRY END
#
#
# ENTRY START
# 1041 站台 zhàn tái platform; railway platform
# ENTRY END
#
#
# ENTRY START
# 1042 章 zhāng chapter; section; order;
# regulation; seal
# ENTRY END
#
#
# ENTRY START
# 1043 长（秘书
# ENTRY END
#
#
# ENTRY START
# 长） zhǎng （mì shū zhǎng
# ） chief; head; leader (secretary
# general)
# ENTRY END
#
#
# ENTRY START
# 1044 掌声 zhǎng shēng applause
# ENTRY END
#
#
# ENTRY START
# 1045 账 zhàng account; debt
# ENTRY END
#
#
# ENTRY START
# 1046 账户 zhànghù account
# ENTRY END
#
#
# ENTRY START
# 1047 涨 zhǎng rise
# ENTRY END
#
#
# ENTRY START
#
# 63
# ENTRY END
#
#
# ENTRY START
#  1049 招 zhāo recruit; trick; attract; beckon
# ENTRY END
#
#
# ENTRY START
# 1050 招聘 zhāopìn recruit
# ENTRY END
#
#
# ENTRY START
# 1051 照样 zhàoyàng all the same; as before
# ENTRY END
#
#
# ENTRY START
# 1052 照耀 zhàoyào Shine
# ENTRY END
#
#
# ENTRY START
# 1053 哲学 zhéxué Philosophy
# ENTRY END
#
#
# ENTRY START
# 1054 这就是说 zhè jiù shì shuō this means that; that is to
# say
# ENTRY END
#
#
# ENTRY START
# 1055 镇 zhèn town; tranquil; suppress;
# press down; keep down
# ENTRY END
#
#
# ENTRY START
# 1056 争夺 zhēngduó Fight for
# ENTRY END
#
#
# ENTRY START
# 1057 整顿 zhěngdùn rectify
# ENTRY END
#
#
# ENTRY START
# 1058 整治 zhěng zhì rectify; renovate; fix
# ENTRY END
#
#
# ENTRY START
# 1059 正当 zhèngdāng proper
# ENTRY END
#
#
# ENTRY START
# 1060 政策 zhèngcè policy
# ENTRY END
#
#
# ENTRY START
# 1061 政党 zhèng dǎng political party
# ENTRY END
#
#
# ENTRY START
# 1062 政权 zhèngquán regime
# ENTRY END
#
#
# ENTRY START
# 1063 症状 zhèngzhuàng Symptom
# ENTRY END
#
#
# ENTRY START
# 1064 之类 zhī lèi such as; and so on
# ENTRY END
#
#
# ENTRY START
# 1065 支撑 zhīchēng brace
# ENTRY END
#
#
# ENTRY START
# 1066 支援 zhīyuán support
# ENTRY END
#
#
# ENTRY START
# 1067 枝 zhī branch
# ENTRY END
#
#
# ENTRY START
#
# 64
# ENTRY END
#
#
# ENTRY START
#  1069 织 zhī knit; weave
# ENTRY END
#
#
# ENTRY START
# 1070 直升机 zhí shēng jī helicopter
# ENTRY END
#
#
# ENTRY START
# 1071 职责 zhí zé duty; responsibility
# ENTRY END
#
#
# ENTRY START
# 1072 止 zhǐ stop; only; just; till; to
# ENTRY END
#
#
# ENTRY START
# 1073 只得 zhǐ dé have to; have no alternative
# but to; be obliged
# ENTRY END
#
#
# ENTRY START
# 1074 只顾 zhǐ gù merely; simply; only care for;
# be absorbed to
# ENTRY END
#
#
# ENTRY START
# 1075 只管 zhǐ guǎn by all means; not hesitate;
# merely; just
# ENTRY END
#
#
# ENTRY START
# 1076 指定 zhǐdìng Appoint
# ENTRY END
#
#
# ENTRY START
# 1077 指数 zhǐ shù index; exponent
# ENTRY END
#
#
# ENTRY START
# 1078 指头 zhǐ tou finger; toe
# ENTRY END
#
#
# ENTRY START
# 1079 指着 zhǐ zhe point; pointing
# ENTRY END
#
#
# ENTRY START
# 1080 至于 zhìyú As for
# ENTRY END
#
#
# ENTRY START
# 1081 治病 zhì bìng treat a disease; treat an
# illness
# ENTRY END
#
#
# ENTRY START
# 1082 智慧 zhìhuì wisdom
# ENTRY END
#
#
# ENTRY START
# 1083 中等 zhōng děng medium; moderate
# ENTRY END
#
#
# ENTRY START
# 1084 中华 zhōng huá China
# ENTRY END
#
#
# ENTRY START
# 1085 中期 zhōng qī mid-term; metaphase
# ENTRY END
#
#
# ENTRY START
#
# 65
#  Chinese and foreign
# ENTRY END
#
#
# ENTRY START
# 1087 忠心 zhōng xīn loyalty; devotion; faithfulness
# ENTRY END
#
#
# ENTRY START
# 1088 钟头 zhōng tóu hour
# ENTRY END
#
#
# ENTRY START
# 1089 肿 zhǒng swollen; bloat; swelling
# ENTRY END
#
#
# ENTRY START
# 1090 种种 zhǒng zhǒng all sorts of; all kinds of; a
# variety of
# ENTRY END
#
#
# ENTRY START
# 1091 粥 zhōu Porridge
# ENTRY END
#
#
# ENTRY START
# 1092 珠宝 zhū bǎo jewelry
# ENTRY END
#
#
# ENTRY START
# 1093 诸位 zhūwèi every one
# ENTRY END
#
#
# ENTRY START
# 1094 主持人 zhǔ chí rén host; presenter
# ENTRY END
#
#
# ENTRY START
# 1095 主角 zhǔ jué lead; protagonist; leading
# actor
# ENTRY END
#
#
# ENTRY START
# 1096 主流 zhǔliú Main stream
# ENTRY END
#
#
# ENTRY START
# 1097 煮 zhǔ cook
# ENTRY END
#
#
# ENTRY START
# 1098 住宅 zhùzhái residence
# ENTRY END
#
#
# ENTRY START
# 1099 驻 zhù station; resident; stationed;
# located at
# ENTRY END
#
#
# ENTRY START
# 1100 柱子 zhù zi post; pillar
# ENTRY END
#
#
# ENTRY START
# 1101 祝愿 zhù yuàn wish
# ENTRY END
#
#
# ENTRY START
# 1102 专用 zhuān yòng special; dedicated
# ENTRY END
#
#
# ENTRY START
# 1103 转 zhuàn turn
# ENTRY END
#
#
# ENTRY START
#
# 66
# ENTRY END
#
#
# ENTRY START
#  1105 赚 zhuàn earn
# ENTRY END
#
#
# ENTRY START
# 1106 赚钱 zhuàn qián make money
# ENTRY END
#
#
# ENTRY START
# 1107 装备 zhuāngbèi equipment
# ENTRY END
#
#
# ENTRY START
# 1108 壮观 zhuàngguān grand; sublime
# ENTRY END
#
#
# ENTRY START
# 1109 追究 zhuījiū Investigate
# ENTRY END
#
#
# ENTRY START
# 1110 捉 zhuō clutch; grasp; hold; capture
# ENTRY END
#
#
# ENTRY START
# 1111 咨询 zīxún Consultation
# ENTRY END
#
#
# ENTRY START
# 1112 自来水 zì lái shuǐ tap water; running water
# ENTRY END
#
#
# ENTRY START
# 1113 自我 zì wǒ oneself; self
# ENTRY END
#
#
# ENTRY START
# 1114 自学 zì xué self-study
# ENTRY END
#
#
# ENTRY START
# 1115 自言自语 zì yán zì yǔ soliloquize; talk to oneself
# ENTRY END
#
#
# ENTRY START
# 1116 自在 zì zài free; comfortable;
# unrestrained
# ENTRY END
#
#
# ENTRY START
# 1117 宗教 zōngjiào Religion
# ENTRY END
#
#
# ENTRY START
# 1118 总部 zǒng bù headquarters; general
# headquarters
# ENTRY END
#
#
# ENTRY START
# 1119 总监 zǒng jiān director; chief inspector
# ENTRY END
#
#
# ENTRY START
# 1120 总经理 zǒng jīng lǐ general manager
# ENTRY END
#
#
# ENTRY START
# 1121 总量 zǒng liàng total; all quantity
# ENTRY END
#
#
# ENTRY START
# 1122 走私 zǒusī smuggle
# ENTRY END
#
#
# ENTRY START
# 1123 奏 zòu play; play music
# ENTRY END
#
#
# ENTRY START
#
# 67
# ENTRY END
#
#
# ENTRY START
#  1125 足 zú foot; leg; sufficient; ample;
# enough; full; fully; as much
# as
# ENTRY END
#
#
# ENTRY START
# 1126 足以 zúyǐ Enough
# ENTRY END
#
#
# ENTRY START
# 1127 族 zú clan; race; nationality
# ENTRY END
#
#
# ENTRY START
# 1128 族（上班
# ENTRY END
#
#
# ENTRY START
# 族） zú （shàng bān zú） a class of things with
# common features or
# attribute (office worker;
# commuter)
# ENTRY END
#
#
# ENTRY START
# 1129 祖父 zǔfù grandfather
# ENTRY END
#
#
# ENTRY START
# 1130 祖国 zǔguó Motherland
# ENTRY END
#
#
# ENTRY START
# 1131 祖母 zǔ mǔ grandmother
# ENTRY END
#
#
# ENTRY START
# 1132 钻 zuàn diamond; jewel; drill
# ENTRY END
#
#
# ENTRY START
# 1133 最佳 zuì jiā optimal; the best; optimum
# ENTRY END
#
#
# ENTRY START
# 1134 最终 zuì zhōng final; ultimate
# ENTRY END
#
#
# ENTRY START
# 1135 罪 zuì sin; crime; guilt; fault; blame
# ENTRY END
#
#
# ENTRY START
# 1136 罪恶 zuì è sin; crime; evil
# ENTRY END
#
#
# ENTRY START
# 1137 作 zuò rise; compose; pretend;
# affect; feel; become; writing;
# work
# ENTRY END
#
#
# ENTRY START
# 1138 作废 zuòfèi cancel, blank out
# ENTRY END
#
#
# ENTRY START
#
# 68
# ENTRY END
